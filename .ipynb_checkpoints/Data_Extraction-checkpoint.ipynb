# %% [markdown]
# # Data Extraction and cleaning

# %% [markdown]
# From Kaggle, we downloaded a dataset containing 380'000 songs from various genres. We will use this dataset as our baseline:
# https://www.kaggle.com/gyani95/380000-lyrics-from-metrolyrics

# %%
import numpy as np
import pandas as pd
from langdetect import detect
import matplotlib.pyplot as plt
import time

# %%
MAIN_GENRES = {'metal', 'pop', 'hip hop', 'country', 'jazz'} # Already have too much songs for rock

# %% [markdown]
# ### Extraction

# %%
filepath = "../kaggleDataset/lyrics_final_clean.csv" #lyrics
lyrics_df = pd.read_csv(filepath)
#lyrics_df.set_index('index', inplace = True)

# %%
print("Number of songs: {}".format(len(lyrics_df)))
lyrics_df.head()
# Out:
# Number of songs: 317015
#             artist genre                                             lyrics  \
# 0  beyonce-knowles   pop  oh baby how you doing\nyou know i m gonna cut ...
# 1  beyonce-knowles   pop  playin  everything so easy\nit s like you seem...
# 2  beyonce-knowles   pop  if you search\nfor tenderness\nit isn t hard t...
# 3  beyonce-knowles   pop  oh oh oh i oh oh oh i\n\nif i wrote a book abo...
# 4  beyonce-knowles   pop  party the people the people the party it s pop...
#
#               song    year
# 0        ego-remix  2009.0
# 1     then-tell-me  2009.0
# 2          honesty  2009.0
# 3  you-are-my-rock  2009.0
# 4    black-culture  2009.0

# %%
genre = 'hip hop'
genre_df = lyrics_df[lyrics_df['genre'] == genre]
artists = set(genre_df['artist'])
print(artists)
# Out:
# {'jean-grae', 'ziggy-marley', 'chuck-inglish', 'g-o-o-d-music', 'de la ghetto', 'cupcakke', 'arrested-development', 'body-count', 'betty-boo', 'doc-gyneco', 'cowboy-troy', 'deltron-3030', 'sylk-e.-fyne', 'tonya-mitchell', 'jedi mind tricks', 'nate-james', 'erick-sermon', 'pharoahe-monch', 'drumma-boy', 'urban-dance-squad', 'dorrough', 'ed-sheeran', 'drei-ros', 'boogiemonsters', 'cheka', 'blue', 'ciara', 'emilia', 'proper-dos', 'brian-doerksen', 'joe-public', 'ess-vee', '3d', "cam'ron", 'the-murderers', 'dope-d-o-d', 'freak-nasty', 'danger-mouse-and-jemini', 'a-b', 'common', 'elzhi', 'blaque', 'ice-cube', '1982', 'chris-webby', 'nancy-wilson', 'jaguar-wright', 'nemesis', 'daily-meds', 'damion-hall', 't-k.a.s.h.', 'dunson', 'el-debarge', 'dizraeli-the-small-gods', 'archive', 'chuckii-booker', 'chingy', 'mc-brains', 'opm', 'mint-condition', 'wayne', 'shai', 'steve-forbert', 'ida-corr', 'young-black-teenagers', 'ross', 'portrait', 'cameron-grey', 'drama', 'castro', 'jeremih', 'al-jarreau', 'grandmaster-melle-mel', 'gucci-crew', 'electrik-red', 'dj-carnage', 'kut-klose', 'dash-flash', 'tyga', 'baby-blue', 'califonia-swag-district', 'future-atl', 'dream warriors', 'b-rock', 'bars-and-melody', 'screwball', 'ciro', 'chief-keef', 'conejo', 'mandisa', 'mos-def', 'califa-thugs', 'cocoa-sarai', 'silk', 'dels', 'slum village', 'ben-j', 'eric-b.-&-rakim', 'bobby-digital', 'tear-da-club-up-thugs', 'zion', 'mikah-9', 'choclair', 'oh no', 'kool-g-rap', 'famous-dex', 'louis-armstrong', 'gramatik', 'krs one', 'talib kweli', 'michael-learns-to-rock', 'syleena-johnson', 'soopafly', 'bone thugs n harmony', 'bunny-wailer', 'euro', 'freestyle', 'doley-bernays', 'faith-evans', 'saint-etienne', 'glenn-jones', 'trina-&-tamara', 'bugatti-boyz', 'eve', 'luther-vandross', 'ultra', 'beverly-crawford', 'ariez-onasis', 'cee-lo', 'bryan-duncan', 'latif', 'lianne-la-havas', 'emilio-rojas', 'justified-ancients-of-mu-mu', 'macy-gray', 'trends-of-culture', 'gemini', 'nas', 'lighthouse-family', 'casey-veggies', 'dj-drama', "fun-lovin'-criminals", 'bio-killaz', '*nsync', 'dj-laz', 'darlene-zschech', 'cold-flamez', 'mike jones', 'analog-brothers', 'az-the-visualiza', 'spoonie gee', 'caron-wheeler', 'consequence', 'dru-hill', 'genetikk', 'big-timers', 'tim-dog', 'b-g-knocc-out', 'amanda', 'usher', 'cool-calm-pete', 'mobb deep', 'biga-ranx', 'calle-13', 'digga', 'freddie-gibbs', 'baby-k', 'afu-ra', 'big-pun', 'outlawz', 'kanye-west', 'eighty4-fly', 'house-of-pain', 'boom-shaka', 'ruby-amanfu', 'remy-shand', 'dj-clue', 'lloyd', 'brooke-candy', 'doom', "kid-'n-play", 'nonchalant', 'malcolm-mclaren', 'maxwell', 'dj-hi-tek', 'cinos', 'everlast', 'fu-schnickens', 'bethel-music', 'the-workhorse-movement', 'raven-symoné', 'esthero', 'm.i.a.', 'profyle', 'brand-new', 'roberta-flack', 'fat-boys', 'bernz', 'eightball-&-mjg', 'death-grips', 'shyheim', 'ready-for-the-world', 'abica', 'blaqstarr', 'the-prodigy', 'brian-fresco', 'mariah-carey', 'ca-h-money-click', 'bravehearts', 'fat-nick', 'cory-asbury', 'amel-larrieux', 'the-procussions', 'lil-suzy', 'rasheeda', 'foxal', 'funkdoobiest', 'dinero', 'masters-of-illusion', 'brian-mcknight', 'fat joe', 'goodie-mob', 'chiddy-bang', 'donmonique', 'chingo-bling', 'simply-smooth', 'roger', 'saul-williams', 'main-source', 'big-pokey', 'honeyz', 'def-manic', 'backbone', 'bizzy-crook', 'three-times-dope', 'the-cross-movement', '112', 'kevin-rudolf', 'arrested development', "ultramagnetic-mc's", 'd-mac', 'potna-deuce', 'booba', 'nappy-roots', 'eddie-murphy', 'jermaine-jackson', 'feloni', 'deach', 'az-yet', 'french-montana-coke-boys', 'danny-brown', 'dave-young', 'juvenile', 'grandmaster-flash', 'aesop rock', 'red-hot-lover-tone', 'groove-theory', 'dem-hoodstarz', 'the-notorious-b.i.g.', 'lil-1/2-dead', 'intoxicated', 'frost', 'fugative', 'kandi', 'dead-celebrity-status', 'justin-warfield', 'point-break', 'cristyle', 'co-ed', 'git-fresh', 'contrast', 'cashis', 'fergie', 'masta ace incorporated', 'euphonik', 'mc-lyte', 'donnie-trumpet', 'd-pryde ...

# %%
art = 'kanye-west'
art_df = genre_df[genre_df['artist'] == art]
art_df
# Out:
#             artist    genre  \
# 303420  kanye-west  hip hop
# 303494  kanye-west  hip hop
# 303495  kanye-west  hip hop
#
#                                                    lyrics  \
# 303420  well it is a weeping and a moaning and a gnash...
# 303494  \nthrow your diamonds in the sky if you feel t...
# 303495  order huh\nyo we at war\nwe at war with terror...
#
#                               song  year
# 303420                       mercy   NaN
# 303494  diamonds-from-sierra-leone   NaN
# 303495                 jesus-walks   NaN

# %%
song = 'jesus-walks'
song = list(art_df[art_df['song'] == song]['lyrics'])
print(song)
# Out:
# ['order huh\nyo we at war\nwe at war with terrorism racism but most of all we at war with ourselves\n\n\ngod show me the way because the devil s tryin  to break me down\n\n\nyou know what the midwest is\nyoung and restless\nwhere restless niggas might snatch ya necklace\nand next these niggas might jack ya lexus\nsomebody tell these niggas who kanye west is\ni walk through the valley of chi where death is\ntop floor of the view alone will leave you breathless\ntry to catch it it s kinda hard\ngetting choked by detectives yeah yeah now check the method\nthey be asking us questions harass and arrest us\nsaying we eat pieces of shit like you for breakfast\nhuh y all eat pieces of shit what s the basis\nwe ain t goin  nowhere but got suits and cases\na trunk full of coke rental car from avis\nmy mama used to say only jesus can save us\nwell mama i know i act a fool\nbut i ll be gone  til november i got packs to move i hope\n\n\ngod show me the way because the devil s tryin  to break me down\n\nthe only thing that i pray is that my feet don t fail me now \n\nand i don t think there is nothing i can do now to right my wrongs\n\ni want to talk to god but i m afraid because we ain t spoke in so long\n\ngod show me the way because the devil s tryin  to break me down\nthe only thing that i pray is that my feet don t fail me now\nand i don t think there is nothing i can do now to right my wrongs\ni want to talk to god but i m afraid because we ain t spoke in so long so long\n\nso long\n\n\nto the hustlers killers murderers drug dealers even the strippers\n\nto the victims of welfare for we living in hell here hell yeah\n\nnow hear ye hear ye want to see thee more clearly\ni know he hear me when my feet get weary\ncause we re the almost nearly extinct\nwe rappers are role models we rap we don t think\ni ain t here to argue about his facial features\nor here to convert atheists into believers\ni m just trying to say the way school need teachers\nthe way kathie lee needed regis that s the way i need jesus\nso here go my single dog radio needs this\nthey said you can rap about anything except for jesus\nthat means guns sex lies video tape\nbut if i talk about god my record won t get played\nhuh\nwell let this take away from my spins\nwhich will probably take away from my ends\nthen i hope this take away from my sins\nand bring the day that i m dreaming about\nnext time i m in the club everybody screaming out\n\n\ngod show me the way because the devil trying to break me down\n\nthe only thing that i pray is that me feet don t fail me now']

# %%
song_html = [song[0].replace('\n', '<br>')]
print(song_html)
# Out:
# ['order huh<br>yo we at war<br>we at war with terrorism racism but most of all we at war with ourselves<br><br><br>god show me the way because the devil s tryin  to break me down<br><br><br>you know what the midwest is<br>young and restless<br>where restless niggas might snatch ya necklace<br>and next these niggas might jack ya lexus<br>somebody tell these niggas who kanye west is<br>i walk through the valley of chi where death is<br>top floor of the view alone will leave you breathless<br>try to catch it it s kinda hard<br>getting choked by detectives yeah yeah now check the method<br>they be asking us questions harass and arrest us<br>saying we eat pieces of shit like you for breakfast<br>huh y all eat pieces of shit what s the basis<br>we ain t goin  nowhere but got suits and cases<br>a trunk full of coke rental car from avis<br>my mama used to say only jesus can save us<br>well mama i know i act a fool<br>but i ll be gone  til november i got packs to move i hope<br><br><br>god show me the way because the devil s tryin  to break me down<br><br>the only thing that i pray is that my feet don t fail me now <br><br>and i don t think there is nothing i can do now to right my wrongs<br><br>i want to talk to god but i m afraid because we ain t spoke in so long<br><br>god show me the way because the devil s tryin  to break me down<br>the only thing that i pray is that my feet don t fail me now<br>and i don t think there is nothing i can do now to right my wrongs<br>i want to talk to god but i m afraid because we ain t spoke in so long so long<br><br>so long<br><br><br>to the hustlers killers murderers drug dealers even the strippers<br><br>to the victims of welfare for we living in hell here hell yeah<br><br>now hear ye hear ye want to see thee more clearly<br>i know he hear me when my feet get weary<br>cause we re the almost nearly extinct<br>we rappers are role models we rap we don t think<br>i ain t here to argue about his facial features<br>or here to convert atheists into believers<br>i m just trying to say the way school need teachers<br>the way kathie lee needed regis that s the way i need jesus<br>so here go my single dog radio needs this<br>they said you can rap about anything except for jesus<br>that means guns sex lies video tape<br>but if i talk about god my record won t get played<br>huh<br>well let this take away from my spins<br>which will probably take away from my ends<br>then i hope this take away from my sins<br>and bring the day that i m dreaming about<br>next time i m in the club everybody screaming out<br><br><br>god show me the way because the devil trying to break me down<br><br>the only thing that i pray is that me feet don t fail me now']

# %% [markdown]
# We will only keep the songs with availaible lyrics ! (Maybe keep the songs with no lyrics as the song name often appears in the lyrics)

# %%
lyrics_df.dropna(axis = 'index', subset = ['lyrics'], inplace = True)
print("Number of songs WITH available lyrics: {}".format(len(lyrics_df)))
# Out:
# Number of songs WITH available lyrics: 266557

# %%
artists = set(lyrics_df["artist"])
genres = set(lyrics_df["genre"])

# %%
print("Genres: {}".format(genres))
print("Number of artists: {}".format(len(artists)))
# Out:
# Genres: {'Jazz', 'Indie', 'Metal', 'Hip-Hop', 'Other', 'Electronic', 'Folk', 'Pop', 'Country', 'Rock', 'R&B', 'Not Available'}
# Number of artists: 14543

# %%
not_available_df = lyrics_df[lyrics_df['genre'] == 'Not Available']
not_available_df.head()
# Out:
#                                song  year       artist          genre  \
# index
# 350             oooh-ooh-saint-nick  2009    dick-mace  Not Available
# 385                 wer-liebe-sucht  2006  daliah-lavi  Not Available
# 386                 es-geht-auch-so  2006  daliah-lavi  Not Available
# 387    liebeslied-jener-sommernacht  2006  daliah-lavi  Not Available
# 388          willst-du-mit-mir-gehn  2006  daliah-lavi  Not Available
#
#                                                   lyrics
# index
# 350    Santa Claus was scootin'across the roof tops '...
# 385    Ist das so schwer\nein kleines Lächeln\nwenn d...
# 386    Der Weg\nden du und ich gegangen\nführt mit ei...
# 387    Rote Schatten warf das Feuer\nhell wie Gold wa...
# 388    Willst Du mit mir gehn,Wenn mein Weg in Dunkel...

# %% [markdown]
# Use the detect library to detect the main language of each song and remove the songs that are detected as NOT english

# %%
def language_of_lyrics(lyrics):
    try:
        lang = detect(lyrics)
        return lang
    except:
        return "no lang"

#lyrics_df['language'] = lyrics_df.apply(lambda row: language_of_lyrics, axis = 1)
"""
list_langs = []
for i, row in lyrics_df.iterrows():
    if i % 1000 == 0:
        print(i)
    lang = language_of_lyrics(row['lyrics'])
    list_langs.append(lang)
"""
# Out:
# "\nlist_langs = []\nfor i, row in lyrics_df.iterrows():\n    if i % 1000 == 0:\n        print(i)\n    lang = language_of_lyrics(row['lyrics'])\n    list_langs.append(lang)\n"

# %%
lyrics_df['language'] = list_langs
english_df = lyrics_df[lyrics_df['language'] == 'en']
print(len(english_df))
english_df.head()
# Out:
# 238239
#                   song  year           artist genre  \
# index
# 0            ego-remix  2009  beyonce-knowles   Pop
# 1         then-tell-me  2009  beyonce-knowles   Pop
# 2              honesty  2009  beyonce-knowles   Pop
# 3      you-are-my-rock  2009  beyonce-knowles   Pop
# 4        black-culture  2009  beyonce-knowles   Pop
#
#                                                   lyrics language
# index
# 0      Oh baby, how you doing?\nYou know I'm gonna cu...       en
# 1      playin' everything so easy,\nit's like you see...       en
# 2      If you search\nFor tenderness\nIt isn't hard t...       en
# 3      Oh oh oh I, oh oh oh I\n[Verse 1:]\nIf I wrote...       en
# 4      Party the people, the people the party it's po...       en

# %%
english_df['genre'] = english_df['genre'].apply(lambda g: g.lower())
# Save the csv file to avoid running the lyrics language detection again
#english_df.to_csv("../kaggleDataset/lyrics_cleaned.csv", index = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### 'Not Available' genre: get rid of the songs or get genre of artist from Spotify ?

# %% [markdown]
# ### Data Exploration

# %%
english_df = pd.read_csv("../kaggleDataset/lyrics_cleaned.csv")
artist_genre_df = pd.read_csv("../kaggleDataset/artists_main_genre.csv")
artist_genre_df.head()
# Out:
#             artist  main genre
# 0  Black Eyed Peas         pop
# 1     Joy Division        rock
# 2   Mint Condition         pop
# 3        Plump DJs  electronic
# 4   Jope Ruonansuu         pop

# %%
n, bins, patches = plt.hist(x = list(english_df["genre"]), bins=np.arange(0,len(set(english_df["genre"])) + 1), color='orange', align = 'left', alpha=0.7, rwidth=0.5)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Genres')
plt.ylabel('Number of artists')
plt.title('Number of artists with the specific genre')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# We keep only the artists with the genre of interests and try to give the same format to artist's names between the 2 dataframes: main_lyrics_df and artist_genre_df in order to remove the artists for which we already have the lyrics from the ones for which we want to fetch the lyrics online.

# %%
main_lyrics_df = english_df[english_df['genre'].isin(MAIN_GENRES)]
print("Ratio of lyrics kept from main genres: {}".format(len(main_lyrics_df) / len(english_df)))

# Give same format of artist names in both dataframes:
main_lyrics_df['artist'] = main_lyrics_df['artist'].apply(lambda a: a.replace('-', ' ').lower()) # beyonce-knowles -> beyonce knowles
artist_genre_df['artist'] = artist_genre_df['artist'].apply(lambda a: a.replace('-', ' ').lower())
# Create dictionary of artist - genre
artist_genre_dict = dict(zip(list(artist_genre_df['artist']), list(artist_genre_df['main genre'])))

# Get the set of artists for which we don't already have the lyrics
artists_to_fetch = set(artist_genre_df['artist']).difference(set(main_lyrics_df['artist']))
print("Artists to fetch number: {} , ratio: {}".format(len(artists_to_fetch), len(artists_to_fetch) / len(set(artist_genre_df['artist']))))
# Out:
# Ratio of lyrics kept from main genres: 0.32715886147943873
# Artists to fetch number: 1657 , ratio: 0.9236343366778149
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %% [markdown]
# Now let's have a small insight of some artists in the main_lyrics_df and how these lyrics look like

# %%
genres_artists_dict = {}
for genre in genres:
    lyrics_genre = main_lyrics_df[main_lyrics_df['genre'] == genre.lower()]
    genres_artists_dict[genre] = set(lyrics_genre['artist'])
    
print("Artists in Metal: {}".format(list(genres_artists_dict['Metal'])[:5]))
# Out:
# Artists in Metal: ['divina enema', 'drifter', 'cadaverous condition', 'avulsed', 'dagoba']

# %% [markdown]
# Get example of lyrics:

# %%
artist = 'architects'
song = 'gravedigger'
example = main_lyrics_df[main_lyrics_df['artist'] == artist]
print(list(example[example['song'] == song]['lyrics']))
# Out:
# ["An iron fist in a velvet glove.\r\nAnother vulture posing as a dove.\r\nDo you have no shame? Look at what you've become.\r\nYou are the reason we are bitter and then some.\r\nBitter and then some.\r\nThey sing of saviors, we sing of sorrow.\r\nBut we're still holding on for dear life.\r\nYou sold us all down the river.\r\nI hope you choke on the vows that you failed to deliver.\r\nYou said you'd change the world, but death still flies east.\r\nThe blind lead the blind, so we bomb for peace.\r\nGravedigger (gravedigger) there's blood on your hands.\r\nYou built this empire on salt and sand.\r\nNot all is fair in love and war.\r\nHistory repeats, we've seen this all before.\r\nWe've given the vampires the keys to the blood bank.\r\nThey say the more things change, the more they stay the same.\r\nWhile the liars leech, the crooked preach.\r\nSo lie through your teeth, lie like you mean it.\r\nIt beggars belief, do you really think that we still fucking believe it?\r\nYou fucking parasite.\r\nThere's no room in here for an honest man,\r\nOnly callous and cold hearts.\r\nGravedigger (gravedigger), there's blood on your hands.\r\nYou built this empire on salt and sand.\r\nNot all is fair in love and war.\r\nHistory repeats, we've seen it all before.\r\nOppressor, you built this empire on salt and sand.\r\nOppressor, you built this empire on salt and sand.\r\nAn iron fist in a velvet glove.\r\nAnother vulture posing as a dove.\r\nDo you have no shame? Look at what you've become.\r\nYou are the reason we are bitter and then some.\r\nBitter and then some.\r\nThey sing of saviors, we sing of sorrow.\r\nBut we're still holding on for dear life."]

# %% [markdown]
# ### Scrapping for more lyrics on https://www.lyricsfreak.com:

# %%
import requests
from bs4 import BeautifulSoup

# %%
url_lyricsfreak = 'https://www.lyricsfreak.com'

# %%
def get_lyrics_from_link(url):
    response = requests.get(url).content
    soup_lyrics = BeautifulSoup(response, "lxml")
    # Get lyrics from the link
    lyrics_html = soup_lyrics.find_all('div', class_= "dn") # found by inspecting the url
    try:
        lyrics = str(lyrics_html).split('content_h">')[1].split('</div>')[0]
    except IndexError:
        # Some lyrics have an url but acces is restricted
        print("Lyrics restricted for URL {}".format(url))
        return ''
    """Do all the cleaning on the lyrics here: maybe keep if only english ?"""
    # Replace line jump (<br/>) with puctuation .
    lyrics_cleaned = lyrics.replace('<br/>', '. ')
    return lyrics_cleaned


# Given an artist name, get all his songs and lyrics available on lyricsfreak
def get_songs_from_artist(artist_name, genre):
    # Convert artist name to right format for the url
    artist = artist_name.lower()
    first_char = artist[0]
    artist_url = artist.replace(' ', '+') # Name with spaces
    url = url_lyricsfreak + '/' + first_char + '/' + artist_url + '/'
    # Get HTML info on URL
    response = requests.get(url).content
    soup = BeautifulSoup(response, "lxml")
    
    # Get all songs from that artist on the website
    songs_html = soup.find_all('a', {'class': 'lf-link lf-link--secondary'})#"td", "colfirst") #colfirst # parameters found by inspecting the url
    songs_name_link = []
    for song in songs_html:
        song = str(song)
        if artist_url + '/' in song:
            try:
                link = song.split(artist_url + '/')[1].split('"')[0]
                song_name = song.split('title="')[1].split(' Lyrics"')[0]
                # Fetch the lyrics for this song
                url_lyrics = url + link
                lyrics = get_lyrics_from_link(url_lyrics)
                if lyrics != '':
                    # Get same format as the rows of the main_lyrics_df
                    year = None
                    language = None
                    songs_name_link.append([song_name, year, artist_name, genre, lyrics, language])
            except:
                print('Error for artist: {}'.format(artist_name))
    return songs_name_link

# %% [markdown]
# Let's run a test on a sample of artists to see if the functions work as expected

# %%
import time

start = time.time()
test_artists = ['Northlane', 'Mac Miller']
test_dict = {test_artists[0]: 'metal', test_artists[1]: 'hip hop'}

# Create empty dataframe to store results
df = pd.Dataframe(columns = list(main_lyrics_df.columns))
for artist in test_artists:
    genre = test_dict[artist]
    artist_lyrics = get_songs_from_artist(artist, genre)
    print("{} - Number of lyrics found: {}".format(artist, len(artist_lyrics)))
    lyrics_test.append(artist_lyrics)
end = time.time()
print(end - start)
# Out:
# Northlane - Number of lyrics found: 32
# Mac Miller - Number of lyrics found: 200
# 37.192687034606934

# %%
songs_per_genre = {}
genres = [g.lower() for g in genres]
for genre in genres:
    songs_per_genre[genre] = len(english_df[english_df["genre"] == genre])
print(songs_per_genre)
print(MAIN_GENRES)
# Out:
# {'jazz': 7351, 'indie': 2975, 'metal': 21532, 'hip-hop': 23035, 'other': 3989, 'electronic': 7016, 'folk': 1790, 'pop': 34807, 'country': 14252, 'rock': 100565, 'r&b': 3348, 'not available': 17579}
# {'jazz', 'pop', 'hip hop', 'country', 'metal'}

# %%
user = "oli"
artists_to_fetch = set(artist_genre_df['artist']).difference(set(main_lyrics_df['artist']))
print("Total length of artists to fetch: {}".format(len(artists_to_fetch)))

if user == "oli":
    genres_to_fetch = ["metal", "jazz", "country"]
elif user == "emma":
    genres_to_fetch = ["hip hop", "pop"]
    
artists_to_fetch = [a for a in artists_to_fetch if artist_genre_dict[a] in genres_to_fetch]
print("Length of artists to fetch for {}: {}".format(user, len(artists_to_fetch)))
# Out:
# Total length of artists to fetch: 1657
# Length of artists to fetch for oli: 457

# %% [markdown]
# Let's fetch all the songs for all the artists for which we don't have their lyrics in the english_df dataframe. In order to get approximately the same number of songs for each genre, we will set a threshold (e.g. 50'000 songs). Once we have fetched online this threshold from a particular genre we make sure not to fetch any more songs from following artists of this genre

# %%
songs_per_genre_copy = songs_per_genre.copy()
THRESHOLD = 50000
# Create empty dataframe to store results
new_lyrics_df = pd.DataFrame(columns = list(main_lyrics_df.columns))

for i, artist in enumerate(artists_to_fetch):
    if i % 20 == 19:
        print("Percentage Completion: {}% , Lyrics Obtained: {}".format(100*i / len(list(artists_to_fetch)), len(new_lyrics_df)))
        secs_sleep = 60
        print("Now sleeping {} seconds".format(secs_sleep))
        time.sleep(secs_sleep)
    genre = artist_genre_dict[artist]
    nbr_songs_of_genre = songs_per_genre_copy[genre]
    if nbr_songs_of_genre < THRESHOLD:
        artist_lyrics = get_songs_from_artist(artist, genre)
        if len(artist_lyrics) == 0:
            print("Artist {} not found on lyricsfreak".format(artist))
        else:
            list_to_df = pd.DataFrame(artist_lyrics, columns = list(main_lyrics_df.columns))
            new_lyrics_df = new_lyrics_df.append(list_to_df)
            songs_per_genre_copy[genre] += len(artist_lyrics)
# Out:
# Artist richie ray & bobby cruz not found on lyricsfreak
# Artist eddie henderson not found on lyricsfreak
# Artist jimmie davis not found on lyricsfreak
# Artist louie ramirez not found on lyricsfreak
# Artist orquesta sublime not found on lyricsfreak
# Artist aram shelton not found on lyricsfreak
# Artist canis dirus not found on lyricsfreak
# Artist charlie walker not found on lyricsfreak
# Artist amber nicholson not found on lyricsfreak
# Artist danilo perez not found on lyricsfreak
# Artist the kitchen not found on lyricsfreak
# Percentage Completion: 4.157549234135668% , Lyrics Obtained: 391
# Now sleeping 60 seconds
# Artist ray barretto not found on lyricsfreak
# Artist oliver lake quintet not found on lyricsfreak
# Artist paul brown not found on lyricsfreak
# Artist adalberto santiago not found on lyricsfreak
# Artist x static not found on lyricsfreak
# Artist karen peck & new river not found on lyricsfreak
# Artist p.o.d not found on lyricsfreak
# Artist ivan parker not found on lyricsfreak
# Artist john tchicai not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/s/skeeter+davis/end+of+the+world_20471362.html
# Percentage Completion: 8.533916849015318% , Lyrics Obtained: 1415
# Now sleeping 60 seconds
# Artist old man's child not found on lyricsfreak
# Artist dave valentin not found on lyricsfreak
# Artist paul taylor not found on lyricsfreak
# Artist renee rosnes not found on lyricsfreak
# Artist ronnie drew not found on lyricsfreak
# Artist oscar pettiford not found on lyricsfreak
# Artist torcuato mariano not found on lyricsfreak
# Artist los munequitos de matanzas not found on lyricsfreak
# Artist dave "baby" cortez not found on lyricsfreak
# Artist string trio of new york not found on lyricsfreak
# Percentage Completion: 12.910284463894968% , Lyrics Obtained: 2000
# Now sleeping 60 seconds
# Artist arkona not found on lyricsfreak
# Artist nouvelle not found on lyricsfreak
# Artist chico hamilton not found on lyricsfreak
# Artist lightnin' hopkins not found on lyricsfreak
# Artist pitchblack not found on lyricsfreak
# Artist perfection not found on lyricsfreak
# Artist the fureys not found on lyricsfreak
# Artist vulture industries not found on lyricsfreak
# Artist the mad capsule markets not found on lyricsfreak
# Percentage Completion: 17.286652078774615% , Lyrics Obtained: 2645
# Now sleeping 60 seconds
# Artist word not found on lyricsfreak
# Artist vince guaraldi not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/s/saosin/7+years_20553212.html
# Lyrics restricted for URL https://www.lyricsfreak.com/s/saosin/i+can+tell+there+was+an+accident+here+earlier_20540922.html
# Artist gold city not found on lyricsfreak
# Artist p.o.d. not found on lyricsfreak
# Artist fudge tunnel not found on lyricsfreak
# Artist christie hennessy not found on lyricsfreak
# Artist roberto torres not found on lyricsfreak
# Percentage Completion: 21.663019693654267% , Lyrics Obtained: 3358
# Now sleeping 60 seconds
# Artist pelt not found on lyricsfreak
# Artist cal tjader not found on lyricsfreak
# Artist gus viseur not found on lyricsfreak
# Artist bobby valentin not found on lyricsfreak
# Artist bill & gloria gaither not found on lyricsfreak
# Artist richard galliano not found on lyricsfreak
# Percentage Completion: 26.039387308533918% , Lyrics Obtained: 4135
# Now sleeping 60 seconds
# Artist gonzalo rubalcaba not found on lyricsfreak
# Artist alphonse mouzon not found on lyricsfreak
# Artist jamie richards not found on lyricsfreak
# Artist cachao not found on lyricsfreak
# Artist johnny pacheco not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/m/memphis+minnie/when+the+levee+breaks_20803259.html
# Artist crusaders not found on lyricsfreak
# Artist lennie tristano not found on lyricsfreak
# Artist kate maki not found on lyricsfreak
# Percentage Completion: 30.415754923413566% , Lyrics Obtained: 4688
# Now sleeping 60 seconds
# Artist el gran combo de puerto rico not found on lyricsfreak
# Artist chris standring not found on lyricsfreak
# Artist k.t. oslin not found on lyricsfreak
# Artist ancient astronauts not found on lyricsfreak
# Artist ed calle not found on lyricsfreak
# Artist bo carter not found on lyricsfreak
# Artist the perrys not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/e/evanescence/orestes_20502682.html
# Lyrics restricted for URL https://www.lyricsfreak.com/e/evanescence/zero_20356327.html
# Percentage Completion: 34.79212253829321% , Lyrics Obtained: 5374
# Now sleeping 60 seconds
# Artist black debbath not found on lyricsfreak
# Artist jeff & sheri easter not found on lyricsfreak
# Artist ulytau not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/r/ray+price/till+death+do+us+part_20318924.html
# Artist dann huff not found on lyricsfreak
# Artist eberhard weber not found on lyricsfreak
# Artist willie bobo not found on lyricsfreak
# Artist borialis not found on lyricsfreak
# Percentage Completion: 39.16849015317287% , Lyrics Obtained: 6519
# Now sleeping 60 seconds
# Artist the exies not found on lyricsfreak
# Artist luiz bonfa not found on lyricsfreak
# Artist w.a.s.p. not found on lyricsfreak
# Artist demonbreed not found on lyricsfreak
# Artist the rambos not found on lyricsfreak
# Artist cursed not found on lyricsfreak
# Artist bobby broom not found on lyricsfreak
# Percentage Completion: 43.544857768052516% , Lyrics Obtained: 7476
# Now sleeping 60 seconds
# Artist alexander zonjic not found on lyricsfreak
# Artist t lavitz not found on lyricsfreak
# Artist orquesta aragon not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/j/johnny+cash/desperado_20186808.html
# Lyrics restricted for URL https://www.lyricsfreak.com/j/johnny+cash/down+there+by+the+train_20191745.html
# Artist lacy j. dalton not found on lyricsfreak
# Artist sylvia patricia not found on lyricsfreak
# Artist legacy five not found on lyricsfreak
# Artist art ensemble of chicago not found on lyricsfreak
# Artist willie rosario not found on lyricsfreak
# Percentage Completion: 47.921225382932164% , Lyrics Obtained: 8248
# Now sleeping 60 seconds
# Artist jeff and sheri easter not found on lyricsfreak
# Artist nestor torres not found on lyricsfreak
# Artist janet paschal not found on lyricsfreak
# Artist (hed) p.e. not found on lyricsfreak
# Artist christian mcbride not found on lyricsfreak
# Artist billy higgins not found on lyricsfreak
# Artist tom collier not found on lyricsfreak
# Artist lockwood not found on lyricsfreak
# Artist abraham laboriel not found on lyricsfreak
# Artist mat maneri not found on lyricsfreak
# Percentage Completion: 52.29759299781182% , Lyrics Obtained: 8700
# Now sleeping 60 seconds
# Artist conjunto clasico not found on lyricsfreak
# Artist the booth brothers not found on lyricsfreak
# Artist poncho sanchez not found on lyricsfreak
# Artist ray vega not found on lyricsfreak
# Artist eddie palmieri not found on lyricsfreak
# Artist mongo santamaria not found on lyricsfreak
# Artist steve smith not found on lyricsfreak
# Artist sonny simmons not found on lyricsfreak
# Artist africando not found on lyricsfreak
# Percentage Completion: 56.67396061269147% , Lyrics Obtained: 9212
# Now sleeping 60 seconds
# Artist nick colionne not found on lyricsfreak
# Artist shelly manne not found on lyricsfreak
# Artist noah lewis not found on lyricsfreak
# Artist bill perkins not found on lyricsfreak
# Artist nichols not found on lyricsfreak
# Artist five bolt main not found on lyricsfreak
# Artist laurindo almeida not found on lyricsfreak
# Artist los van van not found on lyricsfreak
# Percentage Completion: 61.050328227571114% , Lyrics Obtained: 9627
# Now sleeping 60 seconds
# Artist reginaldo bessa not found on lyricsfreak
# Artist hinge not found on lyricsfreak
# Artist russell malone not found on lyricsfreak
# Artist the nelons not found on lyricsfreak
# Artist karen peck and new river not found on lyricsfreak
# Percentage Completion: 65.42669584245077% , Lyrics Obtained: 10400
# Now sleeping 60 seconds
# Artist t.g. sheppard not found on lyricsfreak
# Artist sonora carruseles not found on lyricsfreak
# Artist catia werneck not found on lyricsfreak
# Artist luciana souza not found on lyricsfreak
# Artist the antripodean collective not found on lyricsfreak
# Artist bruce katz band not found on lyricsfreak
# Artist terje lie not found on lyricsfreak
# Artist pete philly & perquisite not found on lyricsfreak
# Artist orquesta broadway not found on lyricsfreak
# Artist hiram bullock not found on lyricsfreak
# Artist goldfish not found on lyricsfreak
# Percentage Completion: 69.80306345733041% , Lyrics Obtained: 10661
# Now sleeping 60 seconds
# Lyrics restricted for URL https://www.lyricsfreak.com/c/conway+twitty/heartache+tonight_20870546.html
# Artist joe mcbride not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/k/kenny+rogers/desperado_20186817.html
# Artist bela fleck and the flecktones not found on lyricsfreak
# Percentage Completion: 74.17943107221006% , Lyrics Obtained: 12039
# Now sleeping 60 seconds
# Artist stefon harris not found on lyricsfreak
# Artist steve morse not found on lyricsfreak
# Artist eddie calvert not found on lyricsfreak
# Artist grachan moncur iii not found on lyricsfreak
# Artist cats in boots not found on lyricsfreak
# Artist degarmo & key not found on lyricsfreak
# Artist coldworld not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nightwish/over+the+hills+and+far+away_10192503.html
# Lyrics restricted for URL https://www.lyricsfreak.com/p/patsy+cline/shake+rattle+and+roll_20213264.html
# Artist frank vignola not found on lyricsfreak
# Percentage Completion: 78.55579868708972% , Lyrics Obtained: 12561
# Now sleeping 60 seconds
# Artist brenda boykin not found on lyricsfreak
# Artist frank stokes not found on lyricsfreak
# Artist soul ballet not found on lyricsfreak
# Artist this moment not found on lyricsfreak
# Artist the florida boys not found on lyricsfreak
# Artist otis spann not found on lyricsfreak
# Artist bobby hutcherson not found on lyricsfreak
# Artist junior kimbrough not found on lyricsfreak
# Percentage Completion: 82.93216630196936% , Lyrics Obtained: 13033
# Now sleeping 60 seconds
# Artist the abominable iron sloth not found on lyricsfreak
# Artist al di meola not found on lyricsfreak
# Artist dope stars inc. not found on lyricsfreak
# Artist jason miles not found on lyricsfreak
# Artist young holt unlimited not found on lyricsfreak
# Percentage Completion: 87.30853391684902% , Lyrics Obtained: 13673
# Now sleeping 60 seconds
# Artist barley bree not found on lyricsfreak
# Artist mance lipscomb not found on lyricsfreak
# Artist joe graves & the diggers not found on lyricsfreak
# Artist charlie byrd not found on lyricsfreak
# Artist the dillinger escape plan not found on lyricsfreak
# Percentage Completion: 91.68490153172867% , Lyrics Obtained: 14446
# Now sleeping 60 seconds
# Lyrics restricted for URL https://www.lyricsfreak.com/d/drowning+pool/shame_20658625.html
# Artist jimmy mcgriff not found on lyricsfreak
# Artist art blakey's jazz messengers not found on lyricsfreak
# Artist streetwize not found on lyricsfreak
# Artist albert ayler not found on lyricsfreak
# Artist lester bowie not found on lyricsfreak
# Artist james taylor quartet not found on lyricsfreak
# Artist yank rachell not found on lyricsfreak
# Percentage Completion: 96.06126914660831% , Lyrics Obtained: 14961
# Now sleeping 60 seconds
# Artist roberto roena not found on lyricsfreak
# Artist flora purim not found on lyricsfreak
# Artist hal russell not found on lyricsfreak
# Artist tito rodriguez not found on lyricsfreak
# Artist hot club of detroit not found on lyricsfreak
# Artist kai winding not found on lyricsfreak
# Artist derek bailey not found on lyricsfreak

# %%
# Save the new lyrics in csv file
#new_lyrics_df.to_csv("../kaggleDataset/lyrics_augmented_" + user +".csv", index = False)

# %% [markdown]
# Combine the lyrics dataframe: lyrics_cleaned.csv with lyrics_augmented_oli.csv and lyrics_augmented_emma.csv

# %%
english_df = pd.read_csv("../kaggleDataset/lyrics_cleaned.csv")
oli_df = pd.read_csv("../kaggleDataset/lyrics_augmented_oli.csv")
emma_df = pd.read_csv("../kaggleDataset/lyrics_augmented_emma.csv")

# %%
oli_emma_df = pd.concat([oli_df, emma_df])
print(len(oli_emma_df) == len(oli_df) + len(emma_df))
oli_emma_df.head()
# Out:
# True
#                   song  year        artist  genre  \
# 0           So In Love   NaN  leroy hutson   jazz
# 1  So In Love With You   NaN  leroy hutson   jazz
# 2        Unforgettable   NaN  leroy hutson   jazz
# 3                  2X4   NaN     metallica  metal
# 4       53rd &amp; 3rd   NaN     metallica  metal
#
#                                               lyrics  language
# 0  (Lyrics are written by Leroy Hutson). . I don'...       NaN
# 1  I don't know what you have got, girl, naw baby...       NaN
# 2  Unforgettable. That's what you are. Unforgetta...       NaN
# 3  I'm gonna make you, shake you, take you. I'm g...       NaN
# 4  One Two Three Four. If you think you can, well...       NaN

# %%
def get_list_langs(df):
    list_langs = []
    for i, row in df.iterrows():
        if i % 1000 == 999:
            print("Completion: {}".format(i / len(df)))
        lang = language_of_lyrics(row['lyrics'])
        list_langs.append(lang)
    return list_langs

# Get to know the languages of the new lyrics in order to keep only the english lyrics
#langs = get_list_langs(oli_emma_df)

# %%
oli_emma_df['language'] = langs
english_oli_emma = oli_emma_df[oli_emma_df['language'] == 'en']
non_english_oli_emma = oli_emma_df[oli_emma_df['language'] != 'en']
print("Number of lyrics in English: {}".format(len(english_oli_emma)))
print("Number of lyrics in other language: {}".format(len(non_english_oli_emma)))
non_english_oli_emma.head()
# Out:
# Number of lyrics in English: 34820
# Number of lyrics in other language: 3983
#                        song  year           artist  genre  \
# 280         Eraser (Polite)   NaN  nine inch nails  metal
# 342             Starfuckers   NaN  nine inch nails  metal
# 1037                 Negrii   NaN    negura bunget  metal
# 1038           Pohvala Hula   NaN    negura bunget  metal
# 1040  Ã…Å¾uier De Solomonar   NaN    negura bunget  metal
#
#                                                  lyrics language
# 280   Need you. Dream you. Find you. Taste you. Use ...       tr
# 342   Starfuckers. Starfuckers. Starfuckers. Starfuc...       de
# 1037  "En nordan at Svartahafi gengr Svidjot en milk...       id
# 1038  Pren vremi vetuste. Dupre reci imbre. Di pin p...       ro
# 1040  Suier de solomonar. Solominer siner suier. Sec...       ro

# %%
full_english_df = pd.concat([english_df, english_oli_emma])
print(len(full_english_df) == len(english_df) + len(english_oli_emma))
#full_english_df.to_csv("../kaggleDataset/lyrics_full_augmented_.csv", index = False)
# Out:
# True

# %%
print(len(full_english_df))
# Out:
# 273059

# %% [markdown]
# ### Getting more jazz lyrics from Marta's dataset of artists and lyricsfreak:

# %%
artist_filepath = "../kaggleDataset/marta_datasets/"
artists_df = pd.read_csv(artist_filepath + 'dataset.csv')
artists_df = artists_df[['name', 'genres', 'followers']]
artists_df.head()
# Out:
#                       name                          genres  followers
# 0             Zachary Levi                    ['broadway']     3752.0
# 1           Zachary Breaux  ['jazz guitar', 'smooth jazz']     1361.0
# 2          The Silhouettes                     ['doo-wop']     1147.0
# 3  Peter & the Silhouettes                              []        0.0
# 4     The Lost Silhouettes                              []        4.0

# %%
def get_artists_from_genre(genre_name, df):
    artists = []
    for i, row in df.iterrows():
        if genre_name in str(row['genres']):
            artists.append(row['name'])
    return artists

jazz_artists = get_artists_from_genre('jazz', artists_df)
print(len(jazz_artists))
# Out:
# 5076

# %%
jazz_artists_df = artists_df[artists_df['name'].isin(jazz_artists)]
jazz_artists_df = jazz_artists_df[jazz_artists_df['followers'] > 2000]
print(len(jazz_artists_df))
jazz_artists_df.head()
# Out:
# 2024
#                name                                             genres  \
# 116       Sam Cooke  ['adult standards', 'brill building pop', 'chi...
# 558  Arild Andersen  ['contemporary jazz', 'dark jazz', 'fourth wor...
# 605    Bobo Stenson                                     ['jazz piano']
# 755  Tierney Sutton                          ['cabaret', 'vocal jazz']
# 832     Ursula 1000  ['acid jazz', 'big beat', 'electro swing', 'nu...
#
#      followers
# 116   574587.0
# 558     2962.0
# 605     2288.0
# 755     6551.0
# 832     4645.0

# %%
# Create empty dataframe to store results
cols = ['song','year','artist','genre','lyrics','language']
new_lyrics_df = pd.DataFrame(columns = cols)

for i, artist in enumerate(jazz_artists_df['name']):
    if i % 20 == 19:
        print("Percentage Completion: {}% , Lyrics Obtained: {}".format(100*i / len(jazz_artists_df), len(new_lyrics_df)))
        secs_sleep = 30
        print("Now sleeping {} seconds".format(secs_sleep))
        time.sleep(secs_sleep)
    artist_lyrics = get_songs_from_artist(artist, 'jazz')
    if len(artist_lyrics) == 0:
        print("Artist {} not found on lyricsfreak".format(artist))
    else:
        list_to_df = pd.DataFrame(artist_lyrics, columns = cols)
        new_lyrics_df = new_lyrics_df.append(list_to_df)
# Out:
# Artist Arild Andersen not found on lyricsfreak
# Artist Bobo Stenson not found on lyricsfreak
# Artist Ketil Bjørnstad not found on lyricsfreak
# Artist Session Victim not found on lyricsfreak
# Artist Free The Robots not found on lyricsfreak
# Artist Morgana King not found on lyricsfreak
# Artist Roberto Torres not found on lyricsfreak
# Artist Fazıl Say not found on lyricsfreak
# Artist Earth, Wind & Fire not found on lyricsfreak
# Percentage Completion: 0.9387351778656127% , Lyrics Obtained: 464
# Now sleeping 30 seconds
# Artist Gerald Albright not found on lyricsfreak
# Artist John Mayall & The Bluesbreakers not found on lyricsfreak
# Artist Suavi not found on lyricsfreak
# Artist Sharon Jones & The Dap-Kings not found on lyricsfreak
# Artist Hexstatic not found on lyricsfreak
# Artist The RH Factor not found on lyricsfreak
# Artist Nils Wülker not found on lyricsfreak
# Artist BWB not found on lyricsfreak
# Artist James P. Johnson not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nina+simone/nobodys+fault+but+mine_20100505.html
# Artist Variety Lab not found on lyricsfreak
# Artist Enrico Rava not found on lyricsfreak
# Percentage Completion: 1.9268774703557312% , Lyrics Obtained: 1083
# Now sleeping 30 seconds
# Artist Andy Montañez not found on lyricsfreak
# Artist The Bar-Kays not found on lyricsfreak
# Artist Terry Riley not found on lyricsfreak
# Artist Miles Bonny not found on lyricsfreak
# Artist Sven-Bertil Taube not found on lyricsfreak
# Artist The Dukes Of Dixieland not found on lyricsfreak
# Artist Brass Construction not found on lyricsfreak
# Artist Lyle Mays not found on lyricsfreak
# Artist Bobby Lyle not found on lyricsfreak
# Artist Ray Brown not found on lyricsfreak
# Artist Ray Brown Trio not found on lyricsfreak
# Artist Wes Montgomery not found on lyricsfreak
# Artist Melt Yourself Down not found on lyricsfreak
# Percentage Completion: 2.9150197628458496% , Lyrics Obtained: 1308
# Now sleeping 30 seconds
# Artist The Neville Brothers not found on lyricsfreak
# Artist Oliver Nelson not found on lyricsfreak
# Artist Euge Groove not found on lyricsfreak
# Artist B.T. Express not found on lyricsfreak
# Artist Mory Kanté not found on lyricsfreak
# Artist Boogie Belgique not found on lyricsfreak
# Artist Gladys Knight & The Pips not found on lyricsfreak
# Artist Grover Washington, Jr. not found on lyricsfreak
# Artist Slakah The Beatchild not found on lyricsfreak
# Artist Quintette du Hot Club de France not found on lyricsfreak
# Artist The Hot Club Of San Francisco not found on lyricsfreak
# Artist Uptown Funk Empire not found on lyricsfreak
# Percentage Completion: 3.9031620553359683% , Lyrics Obtained: 1998
# Now sleeping 30 seconds
# Lyrics restricted for URL https://www.lyricsfreak.com/r/robert+johnson/traveling+riverside+blues_20328824.html
# Artist Houston Person not found on lyricsfreak
# Artist Art Blakey & The Jazz Messengers not found on lyricsfreak
# Artist Booker T. & the M.G.'s not found on lyricsfreak
# Artist Karuan not found on lyricsfreak
# Artist Steve Kuhn not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/m/margaret+whiting/lets+fall+in+love_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/m/margaret+whiting/like+someone+in+love_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/m/margaret+whiting/old+devil+moon_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/m/margaret+whiting/thou+swell_0.html
# Artist El Gran Combo De Puerto Rico not found on lyricsfreak
# Artist Cortijo Y Su Combo not found on lyricsfreak
# Artist John McLaughlin not found on lyricsfreak
# Artist Mike Phillips not found on lyricsfreak
# Artist Ron Carter not found on lyricsfreak
# Percentage Completion: 4.891304347826087% , Lyrics Obtained: 2368
# Now sleeping 30 seconds
# Artist Pearl Django not found on lyricsfreak
# Artist The Kilimanjaro Darkjazz Ensemble not found on lyricsfreak
# Artist Ramsey Lewis Trio not found on lyricsfreak
# Artist Alif Tree not found on lyricsfreak
# Artist Smokey Robinson & The Miracles not found on lyricsfreak
# Artist Laurindo Almeida not found on lyricsfreak
# Artist Ida Sand not found on lyricsfreak
# Artist Steve Smith not found on lyricsfreak
# Artist Ivan Ave not found on lyricsfreak
# Artist Jojo Effect not found on lyricsfreak
# Percentage Completion: 5.879446640316205% , Lyrics Obtained: 2606
# Now sleeping 30 seconds
# Artist The Dillinger Escape Plan not found on lyricsfreak
# Artist De-Phazz not found on lyricsfreak
# Artist J.J. Cale not found on lyricsfreak
# Artist alva noto not found on lyricsfreak
# Artist Jr. Walker & The All Stars not found on lyricsfreak
# Artist Amanda Bergman not found on lyricsfreak
# Artist Mr.B The Gentleman Rhymer not found on lyricsfreak
# Error for artist: Perry Como
# Artist Woody Shaw not found on lyricsfreak
# Artist Vulture Industries not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/n/norah+jones/the+long+way+home_10194747.html
# Artist La Maxima 79 not found on lyricsfreak
# Artist The Cannonball Adderley Quintet not found on lyricsfreak
# Artist Arthur "Big Boy" Crudup not found on lyricsfreak
# Artist Etoile De Dakar not found on lyricsfreak
# Artist Lord Echo not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/v/van+der+graaf+generator/all+that+before_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/v/van+der+graaf+generator/drop+dead_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/v/van+der+graaf+generator/nadirs+big+chance_0.html
# Percentage Completion: 6.867588932806324% , Lyrics Obtained: 3140
# Now sleeping 30 seconds
# Artist Monodeluxe not found on lyricsfreak
# Artist Jazzamor not found on lyricsfreak
# Artist Farid Farjad not found on lyricsfreak
# Artist Ahmet Aslan not found on lyricsfreak
# Artist Jelly Roll Morton not found on lyricsfreak
# Artist Vasas flora och fauna not found on lyricsfreak
# Artist Nekropsi not found on lyricsfreak
# Artist The Haxan Cloak not found on lyricsfreak
# Artist The Helix Nebula not found on lyricsfreak
# Artist Conjunto Clásico not found on lyricsfreak
# Artist Sidsel Endresen not found on lyricsfreak
# Artist Charlotte Dos Santos not found on lyricsfreak
# Artist Oregon not found on lyricsfreak
# Artist Miguel Zenón not found on lyricsfreak
# Artist Akua Naru not found on lyricsfreak
# Artist Everette Harp not found on lyricsfreak
# Percentage Completion: 7.855731225296442% , Lyrics Obtained: 3389
# Now sleeping 30 seconds
# Artist Art Pepper not found on lyricsfreak
# Artist Louis Armstrong & His Hot Seven not found on lyricsfreak
# Artist The New Birth not found on lyricsfreak
# Artist Paul Desmond not found on lyricsfreak
# Artist Desmond Cheese not found on lyricsfreak
# Artist Chico Hamilton not found on lyricsfreak
# Artist Lambert, Hendricks & Ross not found on lyricsfreak
# Artist The Bahama Soul Club not found on lyricsfreak
# Artist Ike & Tina Turner not found on lyricsfreak
# Artist Earl Klugh not found on lyricsfreak
# Artist Harold Melvin & The Blue Notes not found on lyricsfreak
# Percentage Completion: 8.84387351778656% , Lyrics Obtained: 3900
# Now sleeping 30 seconds
# Artist Max Roach not found on lyricsfreak
# Artist Sven Van Hees not found on lyricsfreak
# Artist Mongo Santamaria not found on lyricsfreak
# Artist Artificial Brain not found on lyricsfreak
# Error for artist: Bootsy Collins
# Artist The Algorithm not found on lyricsfreak
# Artist The Brothers Johnson not found on lyricsfreak
# Artist Bobbi Humphrey not found on lyricsfreak
# Artist Bud Powell not found on lyricsfreak
# Artist Bud Shank not found on lyricsfreak
# Artist Mel Tormé not found on lyricsfreak
# Artist Seamus Blake not found on lyricsfreak
# Artist Ben E. King not found on lyricsfreak
# Artist Ahmad Jamal not found on lyricsfreak
# Artist Ahmad Jamal Trio not found on lyricsfreak
# Artist Raashan Ahmad not found on lyricsfreak
# Percentage Completion: 9.83201581027668% , Lyrics Obtained: 3984
# Now sleeping 30 seconds
# Artist Nubya Garcia not found on lyricsfreak
# Artist Marian McPartland not found on lyricsfreak
# Artist Montefiori Cocktail not found on lyricsfreak
# Artist Vijay Iyer Trio not found on lyricsfreak
# Artist Vijay Iyer not found on lyricsfreak
# Artist Italian Secret Service not found on lyricsfreak
# Artist Incesaz not found on lyricsfreak
# Artist Roscoe Mitchell not found on lyricsfreak
# Artist Richard Elliot not found on lyricsfreak
# Artist DJ Cam not found on lyricsfreak
# Artist Lionel Loueke not found on lyricsfreak
# Artist The Electric Swing Circus not found on lyricsfreak
# Percentage Completion: 10.820158102766799% , Lyrics Obtained: 4245
# Now sleeping 30 seconds
# Artist Emerson, Lake & Palmer not found on lyricsfreak
# Artist Semiramis Pekkan not found on lyricsfreak
# Artist Nils Landgren Funk Unit not found on lyricsfreak
# Artist Septeto Santiaguero not found on lyricsfreak
# Artist 11 Acorn Lane not found on lyricsfreak
# Artist Eric Darius not found on lyricsfreak
# Artist Mary Lou Williams not found on lyricsfreak
# Artist Ibrahim Maalouf not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/aquellos+ojos+verdes_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/ay+candela_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/candela_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/como+fue_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/copla+guajira_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/de+camino+a+la+vereda_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/fuiste+cruel_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/hay+que+entrarle+a+palos+a+se_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/herido+de+sombras_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/la+m+sica+cubana_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/mami+me+gust_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/melod+a+del+r+o_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/naufragio_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/nuestra+ultima+cita_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/oye+el+consejo_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/perfume+de+gardenias_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/i/ibrahim+ferrer/qui+reme+mucho_0.html
# Artist Abdullah Ibrahim not found on lyricsfreak
# Artist The Headhunters not found on lyricsfreak
# Artist Curtis Fuller not found on lyricsfreak
# Artist Alfredo Rodriguez not found on lyricsfreak
# Artist Carol Welsman not found on lyricsfreak
# Artist Dr. John not found on lyricsfreak
# Artist Balla Et Ses Balladins not found on lyricsfreak
# Artist Godspeed You! Black Emperor not found on lyricsfreak
# Percentage Completion: 11.808300395256918% , Lyrics Obtained: 4365
# Now sleeping 30 seconds
# Artist Idris Muhammad not found on lyricsfreak
# Artist Tülay German not found on lyricsfreak
# Artist An Endless Sporadic not found on lyricsfreak
# Artist John Abercrombie not found on lyricsfreak
# Artist The Dining Rooms not found on lyricsfreak
# Artist Brad Mehldau not found on lyricsfreak
# Artist Brad Mehldau Trio not found on lyricsfreak
# Artist Niels-Henning Ørsted Pedersen not found on lyricsfreak
# Artist Althea Rene not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/a+little+bit+independent_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/after+you+get+what+you+want+you+dont+want+it_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/ah+the+apple+trees+when+the+world+was+young_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/all+by+myself_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/arrivederci+roma+goodbye+to+rome_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/back+home+again+in+indiana_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/breezin+along+with+the+breeze_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/crazy+rhythm_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/dont+let+your+eyes+go+shopping+for+your+heart_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/down+by+the+old+mill+stream_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/gbye+now_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/god+rest+you+merry+gentlemen+english_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/gone+with+the+draft_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/i+could+have+danced+all+night_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/i+found+a+million+dollar+baby+in+a+five+and+ten+cent+store_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/i+got+rhythm_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/i+heard+you+cried+last+night_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/i+may+be+wrong+but+i+think+youre+wonderful_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/i+wanna+be+a+friend+of+yours_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/in+the+good+old+summertime_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/jumpin+at+capitol_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/just+as+much+as+ever_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/knock+me+a+kiss_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/liza+all+the+cloudsll+roll+away_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/n/nat+king+cole/mutiny+in+the+nursery_0.html
# Artist Nat King Cole Trio not found on lyricsfreak
# Percentage Completion: 12.796442687747035% , Lyrics Obtained: 4947
# Now sleeping 30 seconds
# Artist Naoki Kenji not found on lyricsfreak
# Artist Hypnotic Brass Ensemble not found on lyricsfreak
# Artist Franska Trion not found on lyricsfreak
# Artist Emilie-Claire Barlow not found on lyricsfreak
# Artist Kesmeşeker not found on lyricsfreak
# Artist mor ve ötesi not found on lyricsfreak
# Artist Takuya Kuroda not found on lyricsfreak
# Artist The Andrews Sisters not found on lyricsfreak
# Artist Charles Mingus not found on lyricsfreak
# Artist Herb Ellis not found on lyricsfreak
# Artist John Coltrane Quartet not found on lyricsfreak
# Artist Paolo Fresu not found on lyricsfreak
# Artist Dutty Moonshine not found on lyricsfreak
# Artist Chucho Valdés not found on lyricsfreak
# Percentage Completion: 13.784584980237154% , Lyrics Obtained: 5524
# Now sleeping 30 seconds
# Artist Bebo Valdés not found on lyricsfreak
# Artist Vicentico Valdés not found on lyricsfreak
# Artist Cal Tjader not found on lyricsfreak
# Artist William Basinski not found on lyricsfreak
# Artist Jazz Pistols not found on lyricsfreak
# Artist Tortured Soul not found on lyricsfreak
# Artist Sly5thAve not found on lyricsfreak
# Artist GoldFish not found on lyricsfreak
# Artist Afro-Cuban All Stars not found on lyricsfreak
# Percentage Completion: 14.772727272727273% , Lyrics Obtained: 6143
# Now sleeping 30 seconds
# Artist Monguito not found on lyricsfreak
# Artist Baptiste Trotignon not found on lyricsfreak
# Artist Cindy Bradley not found on lyricsfreak
# Artist The Fabulous Thunderbirds not found on lyricsfreak
# Artist Roy Ayers Ubiquity not found on lyricsfreak
# Artist The J.B.'s not found on lyricsfreak
# Artist Béla Fleck and the Flecktones not found on lyricsfreak
# Artist Mammal Hands not found on lyricsfreak
# Artist Freedom Dub not found on lyricsfreak
# Artist Steve Coleman not found on lyricsfreak
# Percentage Completion: 15.76086956521739% , Lyrics Obtained: 6717
# Now sleeping 30 seconds
# Artist Adam Nitti not found on lyricsfreak
# Artist Ben Webster not found on lyricsfreak
# Artist Feridun Düzağaç not found on lyricsfreak
# Artist Tolga Çandar not found on lyricsfreak
# Artist Didier Lockwood not found on lyricsfreak
# Artist Hubert Laws not found on lyricsfreak
# Artist Arthur Lyman not found on lyricsfreak
# Artist Guillermo Portabales not found on lyricsfreak
# Artist Saint Privat not found on lyricsfreak
# Artist Nicolas Repac not found on lyricsfreak
# Artist Martha Reeves & The Vandellas not found on lyricsfreak
# Artist Studio Apartment not found on lyricsfreak
# Artist Gabriel Garzón-Montano not found on lyricsfreak
# Artist Janek Gwizdala not found on lyricsfreak
# Artist Special EFX not found on lyricsfreak
# Artist Theo Croker not found on lyricsfreak
# Percentage Completion: 16.74901185770751% , Lyrics Obtained: 7011
# Now sleeping 30 seconds
# Artist Dutch Swing College Band not found on lyricsfreak
# Artist Kendrick Scott Oracle not found on lyricsfreak
# Artist Acoustic Alchemy not found on lyricsfreak
# Artist João Gilberto not found on lyricsfreak
# Artist Walter Smith III not found on lyricsfreak
# Artist Mystic Diversions not found on lyricsfreak
# Artist İlhan İrem not found on lyricsfreak
# Artist Their Dogs Were Astronauts not found on lyricsfreak
# Artist Anders Widmark Trio not found on lyricsfreak
# Artist Mike Bloomfield not found on lyricsfreak
# Artist Joscho Stephan not found on lyricsfreak
# Artist The John Scofield Band not found on lyricsfreak
# Artist The Pasadena Roof Orchestra not found on lyricsfreak
# Artist Lonnie Liston Smith and the Cosmic Echoes not found on lyricsfreak
# Percentage Completion: 17.73715415019763% , Lyrics Obtained: 7198
# Now sleeping 30 seconds
# Artist Pat Martino not found on lyricsfreak
# Artist Steve Morse not found on lyricsfreak
# Artist Get The Blessing not found on lyricsfreak
# Artist Paul Jackson, Jr. not found on lyricsfreak
# Artist Tape Five not found on lyricsfreak
# Artist Dojo Cuts not found on lyricsfreak
# Artist Uneven Structure not found on lyricsfreak
# Artist Cæcilie Norby not found on lyricsfreak
# Artist Toninho Horta not found on lyricsfreak
# Error for artist: Joe Henderson
# Artist John Lewis not found on lyricsfreak
# Percentage Completion: 18.725296442687746% , Lyrics Obtained: 7668
# Now sleeping 30 seconds
# Artist Ulf Wakenius not found on lyricsfreak
# Artist Joe McBride not found on lyricsfreak
# Artist Sam & Dave not found on lyricsfreak
# Artist Lack Of Afro not found on lyricsfreak
# Artist Lafayette Afro Rock Band not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/m/memphis+minnie/when+the+levee+breaks_20803259.html
# Artist Cahit Berkay not found on lyricsfreak
# Artist Diggs Duke not found on lyricsfreak
# Artist Fat Freddy's Drop not found on lyricsfreak
# Error for artist: Dizzy Gillespie
# Artist Nicole Henry not found on lyricsfreak
# Error for artist: Gregory Porter
# Artist Ebo Taylor not found on lyricsfreak
# Artist Gerry Mulligan not found on lyricsfreak
# Artist Louis Jordan & His Tympany Five not found on lyricsfreak
# Artist Louis Armstrong & His Hot Five not found on lyricsfreak
# Percentage Completion: 19.713438735177867% , Lyrics Obtained: 7973
# Now sleeping 30 seconds
# Artist Pamela Williams not found on lyricsfreak
# Artist Richard Galliano not found on lyricsfreak
# Artist Art Farmer not found on lyricsfreak
# Artist Alfa Mist not found on lyricsfreak
# Artist Hugo Kant not found on lyricsfreak
# Artist The Manhattan Transfer not found on lyricsfreak
# Artist Beegie Adair not found on lyricsfreak
# Artist Stephane Wrembel not found on lyricsfreak
# Artist Cecil Taylor not found on lyricsfreak
# Percentage Completion: 20.701581027667984% , Lyrics Obtained: 8482
# Now sleeping 30 seconds
# Artist Dave Pike not found on lyricsfreak
# Artist The Quantic Soul Orchestra not found on lyricsfreak
# Artist Art Ensemble Of Chicago not found on lyricsfreak
# Artist Nate Smith not found on lyricsfreak
# Artist Jill Barber not found on lyricsfreak
# Artist DJ Disse not found on lyricsfreak
# Artist Oli Silk not found on lyricsfreak
# Artist Nick Colionne not found on lyricsfreak
# Artist Widek not found on lyricsfreak
# Artist Rebirth Brass Band not found on lyricsfreak
# Artist Cosmosquad not found on lyricsfreak
# Artist Urban Knights not found on lyricsfreak
# Artist The Sax Pack not found on lyricsfreak
# Artist Gypsy Jazz Caravan not found on lyricsfreak
# Percentage Completion: 21.6897233201581% , Lyrics Obtained: 8619
# Now sleeping 30 seconds
# Artist Sly & The Family Stone not found on lyricsfreak
# Artist Blue Lab Beats not found on lyricsfreak
# Artist Braxton Brothers not found on lyricsfreak
# Artist Scott Hamilton not found on lyricsfreak
# Artist Chantae Cann not found on lyricsfreak
# Artist Trio Matamoros not found on lyricsfreak
# Artist Tal Farlow not found on lyricsfreak
# Artist Jimmy Rosenberg not found on lyricsfreak
# Artist Adalberto Santiago not found on lyricsfreak
# Artist Marvin Santiago not found on lyricsfreak
# Artist Rubén Blades not found on lyricsfreak
# Artist Mestís not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/j/joe+sample/my+one+and+only+love_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/s/solomon+burke/baby+come+on+home_20853000.html
# Artist Brian Blade not found on lyricsfreak
# Percentage Completion: 22.677865612648223% , Lyrics Obtained: 8906
# Now sleeping 30 seconds
# Artist Snarky Puppy not found on lyricsfreak
# Artist Marion Meadows not found on lyricsfreak
# Artist Swing Republic not found on lyricsfreak
# Artist Tosca not found on lyricsfreak
# Artist Tosca not found on lyricsfreak
# Artist Lalo Rodriguez not found on lyricsfreak
# Artist Tony Allen not found on lyricsfreak
# Artist Minus 8 not found on lyricsfreak
# Artist Sonny Boy Williamson II not found on lyricsfreak
# Artist Liquid Tension Experiment not found on lyricsfreak
# Percentage Completion: 23.66600790513834% , Lyrics Obtained: 9127
# Now sleeping 30 seconds
# Artist Orquesta Zodiac not found on lyricsfreak
# Artist Dawn of Midi not found on lyricsfreak
# Artist Beyond Creation not found on lyricsfreak
# Artist Nai Palm not found on lyricsfreak
# Artist Irakere not found on lyricsfreak
# Artist Sarah McKenzie not found on lyricsfreak
# Artist Hardkandy not found on lyricsfreak
# Artist Soneros De Verdad not found on lyricsfreak
# Artist Ben Tankard not found on lyricsfreak
# Artist Tanju Okan not found on lyricsfreak
# Artist The Juju Orchestra not found on lyricsfreak
# Artist Taylor Deupree not found on lyricsfreak
# Artist Eddie "Lockjaw" Davis not found on lyricsfreak
# Artist David Torn not found on lyricsfreak
# Artist Bill Stewart not found on lyricsfreak
# Percentage Completion: 24.654150197628457% , Lyrics Obtained: 9310
# Now sleeping 30 seconds
# Artist Carla Bley not found on lyricsfreak
# Artist Chris Barber not found on lyricsfreak
# Artist 3rd Force not found on lyricsfreak
# Artist Charlie Rouse not found on lyricsfreak
# Artist Braxton Cook not found on lyricsfreak
# Artist Gil Scott-Heron not found on lyricsfreak
# Artist Gretchen Parlato not found on lyricsfreak
# Artist Tito Gomez not found on lyricsfreak
# Artist Gato Barbieri not found on lyricsfreak
# Artist Jimmie Lunceford not found on lyricsfreak
# Artist Exivious not found on lyricsfreak
# Artist 30/70 not found on lyricsfreak
# Percentage Completion: 25.642292490118578% , Lyrics Obtained: 9759
# Now sleeping 30 seconds
# Artist Clark Terry not found on lyricsfreak
# Artist Lead Belly not found on lyricsfreak
# Artist Floating Points not found on lyricsfreak
# Artist Tigran Hamasyan not found on lyricsfreak
# Artist Tim Bowman not found on lyricsfreak
# Artist Jan Lundgren Trio not found on lyricsfreak
# Artist Subterranean Masquerade not found on lyricsfreak
# Artist Eric Lau not found on lyricsfreak
# Artist Larry Carlton not found on lyricsfreak
# Artist Paul Taylor not found on lyricsfreak
# Artist The Aristocrats not found on lyricsfreak
# Artist Charlie Parker Quartet not found on lyricsfreak
# Artist Zoot Sims not found on lyricsfreak
# Percentage Completion: 26.630434782608695% , Lyrics Obtained: 10015
# Now sleeping 30 seconds
# Artist Derrick Hodge not found on lyricsfreak
# Artist Wax Poetic not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/aint+it+funny+how+time+slips+away_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/call+me+the+breeze_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/danny+boy_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/detour_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/dont+let+the+stars+get+in+your+eyes_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/far+away+places_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/funny+how+time+slips+away_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/gone+to+shiloh_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/good+time+charlies+got+the+blues_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/he+stopped+loving+her+today_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/heartbreak+hotel_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/hearts+have+turned+to+stone_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/i+couldnt+believe+it+was+true_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/i+really+miss+you_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/i+should+have+sent+roses_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/if+it+wasnt+for+bad_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/it+came+upon+a+midnight+clear_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/ive+just+seen+a+face_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/me+baby+jane_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/medley+jumpin+jack+flashyoung+blood_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/never+too+old+to+hold+somebody_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/round+midnight_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/sioux+city+sue_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/smoke+gets+in+your+eyes_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/spanish+harlem_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/summertime_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/superstar_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/tennessee+waltz_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/the+battle+of+new+orleans_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/the+best+part+of+the+day_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/the+shadow+of+your+smile_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/the+very+thought+of+you_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/the+wild+side+of+life_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/theres+no+tomorrow_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/tumbling+tumbleweeds_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/leon+russell/you+win+again_0.html
# Artist Orquesta Broadway not found on lyricsfreak
# Artist Gene Ammons not found on lyricsfreak
# Artist Hank Mobley not found on lyricsfreak
# Artist Joyce Cooling not found on lyricsfreak
# Artist 3-11 Porter not found on lyricsfreak
# Artist Chantal Chamberland not found on lyricsfreak
# Artist Native Construct not found on lyricsfreak
# Artist Doug Johns not found on lyricsfreak
# Artist Willie Colón not found on lyricsfreak
# Artist The Greyboy Allstars not found on lyricsfreak
# Artist Courtney Pine not found on lyricsfreak
# Percentage Completion: 27.618577075098813% , Lyrics Obtained: 10273
# Now sleeping 30 seconds
# Artist Olle Adolphson not found on lyricsfreak
# Artist Zülfü Livaneli not found on lyricsfreak
# Artist Stanley Turrentine not found on lyricsfreak
# Artist Edip Akbayram not found on lyricsfreak
# Artist NG La Banda not found on lyricsfreak
# Artist Harry Connick, Jr. not found on lyricsfreak
# Artist Dorothy Ashby not found on lyricsfreak
# Artist Heroin And Your Veins not found on lyricsfreak
# Artist Jefre Cantu-Ledesma not found on lyricsfreak
# Artist Chimp Spanner not found on lyricsfreak
# Artist Barney Kessel not found on lyricsfreak
# Artist Hint not found on lyricsfreak
# Percentage Completion: 28.606719367588934% , Lyrics Obtained: 10730
# Now sleeping 30 seconds
# Artist Oz Noy not found on lyricsfreak
# Artist Puerto Rican Power not found on lyricsfreak
# Artist Aaron Parks not found on lyricsfreak
# Artist Yeni Türkü not found on lyricsfreak
# Artist Annette Peacock not found on lyricsfreak
# Artist John Zorn not found on lyricsfreak
# Artist Paul Chambers not found on lyricsfreak
# Artist The Funky Lowlives not found on lyricsfreak
# Artist Svante Thuresson not found on lyricsfreak
# Artist Sabrina Malheiros not found on lyricsfreak
# Artist Geri Allen not found on lyricsfreak
# Percentage Completion: 29.59486166007905% , Lyrics Obtained: 11274
# Now sleeping 30 seconds
# Artist Roberto Roena not found on lyricsfreak
# Artist Roberto Roena Y Su Apollo Sound not found on lyricsfreak
# Artist Mecca:83 not found on lyricsfreak
# Artist Susie Arioli not found on lyricsfreak
# Artist Terri Lyne Carrington not found on lyricsfreak
# Artist Flora Purim not found on lyricsfreak
# Artist Brett Garsed not found on lyricsfreak
# Artist Spyro Gyra not found on lyricsfreak
# Artist Down To The Bone not found on lyricsfreak
# Artist Grails not found on lyricsfreak
# Artist Dictaphone not found on lyricsfreak
# Artist Inger Marie Gundersen not found on lyricsfreak
# Artist bonobos not found on lyricsfreak
# Artist Sidney Bechet not found on lyricsfreak
# Percentage Completion: 30.58300395256917% , Lyrics Obtained: 11553
# Now sleeping 30 seconds
# Artist Deep Dive Corp. not found on lyricsfreak
# Artist Charlie Parker Sextet not found on lyricsfreak
# Artist GoGo Penguin not found on lyricsfreak
# Artist Ezginin Günlügü not found on lyricsfreak
# Artist Menahan Street Band not found on lyricsfreak
# Artist Yasemin Mori not found on lyricsfreak
# Artist Gerry Mulligan Quartet not found on lyricsfreak
# Artist Goran Kajfes not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/l/louis+armstrong/as+time+goes+by_20320692.html
# Artist B.B. King not found on lyricsfreak
# Artist Seb Wildblood not found on lyricsfreak
# Artist Levent Yüksel not found on lyricsfreak
# Percentage Completion: 31.57114624505929% , Lyrics Obtained: 12279
# Now sleeping 30 seconds
# Artist Orange Pekoe not found on lyricsfreak
# Artist Anthony Valadez not found on lyricsfreak
# Artist Stefano Bollani not found on lyricsfreak
# Artist The Brecker Brothers not found on lyricsfreak
# Artist McCoy Tyner Trio not found on lyricsfreak
# Artist Can Atilla not found on lyricsfreak
# Artist Tromboranga not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/m/marvin+gaye/when+a+man+loves+a+woman_20613866.html
# Artist Fahir Atakoğlu not found on lyricsfreak
# Artist Alain Caron not found on lyricsfreak
# Artist Kalabrese not found on lyricsfreak
# Artist Rosalia De Souza not found on lyricsfreak
# Artist Burhan Öçal not found on lyricsfreak
# Artist Nükhet Duru not found on lyricsfreak
# Artist Steps Ahead not found on lyricsfreak
# Percentage Completion: 32.559288537549406% , Lyrics Obtained: 12624
# Now sleeping 30 seconds
# Artist Gary Peacock not found on lyricsfreak
# Artist Brooklyn Funk Essentials not found on lyricsfreak
# Artist Aldo Romano not found on lyricsfreak
# Artist Protassov not found on lyricsfreak
# Artist Medeski Scofield Martin & Wood not found on lyricsfreak
# Artist Benny Green not found on lyricsfreak
# Artist Wynton Marsalis Septet not found on lyricsfreak
# Artist Flanger not found on lyricsfreak
# Artist Gerardo Frisina not found on lyricsfreak
# Artist Zu not found on lyricsfreak
# Artist Arve Henriksen not found on lyricsfreak
# Percentage Completion: 33.547430830039524% , Lyrics Obtained: 12978
# Now sleeping 30 seconds
# Error for artist: Duke Ellington
# Artist Art Tatum not found on lyricsfreak
# Artist Adam Rafferty not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/b/brenda+russell/le+restaurant_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/brenda+russell/shes+in+love_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/brenda+russell/the+tracks+of+my+tears_0.html
# Artist Svarte Greiner not found on lyricsfreak
# Artist Esbjörn Svensson Trio not found on lyricsfreak
# Artist Pete Josef not found on lyricsfreak
# Error for artist: Frank Zappa
# Error for artist: Frank Zappa
# Error for artist: Frank Zappa
# Error for artist: Frank Zappa
# Error for artist: Frank Zappa
# Error for artist: Frank Zappa
# Error for artist: Frank Zappa
# Error for artist: Frank Zappa
# Artist Fantomas not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/t/the+puppini+sisters/all+i+want+for+christmas_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/t/the+puppini+sisters/in+the+mood_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/t/the+puppini+sisters/it+dont+mean+a+thing+if+it+aint+got+that+swing_0.html
# Artist Bart & Baker not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/l/la+lupe/el+carbonero_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/la+lupe/fever_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/l/la+lupe/going+out+of+my+head_0.html
# Artist Lonnie Liston Smith not found on lyricsfreak
# Artist Shawn Lane not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/e/ernestine+anderson/on+my+own_0.html
# Percentage Completion: 34.53557312252964% , Lyrics Obtained: 13711
# Now sleeping 30 seconds
# Artist Butcher Brown not found on lyricsfreak
# Artist Marquis Hill not found on lyricsfreak
# Artist Stochelo Rosenberg not found on lyricsfreak
# Artist Nekta not found on lyricsfreak
# Artist Machinefabriek not found on lyricsfreak
# Artist Pérez Prado not found on lyricsfreak
# Artist Lou Donaldson not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/l/lou+rawls/bring+it+on+home_20858012.html
# Artist Django Reinhardt not found on lyricsfreak
# Artist Zara McFarlane not found on lyricsfreak
# Artist Mr. Scruff not found on lyricsfreak
# Artist Mr. Bungle not found on lyricsfreak
# Artist John Surman not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/a+fine+romance_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/between+the+devil+and+the+deep+blue+sea_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/heres+that+rainy+day_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/how+about+you_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/i+got+it+bad+and+that+aint+good_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/i+only+have+eyes+for+you_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/isnt+this+a+lovely+day_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/it+might+as+well+be+spring_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/ive+got+you+under+my+skin_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/like+someone+in+love_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/love+for+sale_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/love+walked+in_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/more+than+you+know_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/my+blue+heaven_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/my+heart+stood+still_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/oh+lady+be+good_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/pick+yourself+up_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/polka+dots+and+moonbeams_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/september+song_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/singing+in+the+rain_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/someone+to+watch+over+me_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/stairway+to+the+stars_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/sweet+lorraine_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/that+old+black+magic_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/the+gravy+waltz_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/the+song+is+ended_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/there+is+no+greater+love_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/theres+a+small+hotel_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/you+make+me+feel+so+young_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/o/oscar+peterson+trio/younger+than+springtime_0.html
# Error for artist: Oscar Peterson
# Percentage Completion: 35.523715415019765% , Lyrics Obtained: 14362
# Now sleeping 30 seconds
# Artist Bibi Tanga & The Selenites not found on lyricsfreak
# Artist Marc Ribot not found on lyricsfreak
# Artist Paul Brown not found on lyricsfreak
# Artist Bohren & Der Club Of Gore not found on lyricsfreak
# Artist Héctor Lavoe not found on lyricsfreak
# Artist Andrew Hill not found on lyricsfreak
# Artist Mariam The Believer not found on lyricsfreak
# Artist Pomegranate Tiger not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/j/johnny+winter/kiss+tomorrow+goodbye_20755784.html
# Artist Baby Mammoth not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/b/baden+powell/garota+de+ipanema_0.html
# Artist Simon Phillips not found on lyricsfreak
# Artist Cécile McLorin Salvant not found on lyricsfreak
# Artist The Dirty Dozen Brass Band not found on lyricsfreak
# Percentage Completion: 36.51185770750988% , Lyrics Obtained: 14678
# Now sleeping 30 seconds
# Artist Illinois Jacquet not found on lyricsfreak
# Artist Russ Freeman not found on lyricsfreak
# Artist Bobby "Blue" Bland not found on lyricsfreak
# Artist MFÖ not found on lyricsfreak
# Artist Göksel not found on lyricsfreak
# Artist Nils not found on lyricsfreak
# Artist Georg Riedel not found on lyricsfreak
# Artist Mathias Eick not found on lyricsfreak
# Artist New Swing Sextet not found on lyricsfreak
# Artist Gilad Hekselman not found on lyricsfreak
# Artist Wayne Gorbea not found on lyricsfreak
# Percentage Completion: 37.5% , Lyrics Obtained: 15007
# Now sleeping 30 seconds
# Artist Tommy Flanagan not found on lyricsfreak
# Artist Willie Bobo not found on lyricsfreak
# Artist Doğan Canku not found on lyricsfreak
# Artist The Greg Foat Group not found on lyricsfreak
# Artist Stéphane Pompougnac not found on lyricsfreak
# Artist C.V. Jørgensen not found on lyricsfreak
# Error for artist: Shirley Horn
# Artist Stuart Hamm not found on lyricsfreak
# Artist Adam Rogers not found on lyricsfreak
# Artist David Murray not found on lyricsfreak
# Artist Yaşar Kurt not found on lyricsfreak
# Artist Clifford Brown not found on lyricsfreak
# Artist Kruder & Dorfmeister not found on lyricsfreak
# Artist J.J. Johnson not found on lyricsfreak
# Artist The Dave Brubeck Quartet not found on lyricsfreak
# Percentage Completion: 38.48814229249012% , Lyrics Obtained: 15344
# Now sleeping 30 seconds
# Artist The Modern Jazz Quartet not found on lyricsfreak
# Artist Susanna not found on lyricsfreak
# Artist Papa Bue's Viking Jazzband not found on lyricsfreak
# Artist Arto Tunçboyacıyan not found on lyricsfreak
# Artist Birsen Tezer not found on lyricsfreak
# Artist Erik Truffaz not found on lyricsfreak
# Artist The Mount Fuji Doomjazz Corporation not found on lyricsfreak
# Artist Fuat Saka not found on lyricsfreak
# Artist Pleasure not found on lyricsfreak
# Artist Les doigts de l'homme not found on lyricsfreak
# Artist Chick Corea Elektric Band not found on lyricsfreak
# Artist Trioscapes not found on lyricsfreak
# Artist Keith Jarrett Trio not found on lyricsfreak
# Artist Trilok Gurtu not found on lyricsfreak
# Percentage Completion: 39.476284584980235% , Lyrics Obtained: 15527
# Now sleeping 30 seconds
# Artist Vince Guaraldi not found on lyricsfreak
# Artist Bill Charlap not found on lyricsfreak
# Artist Bill Charlap Trio not found on lyricsfreak
# Artist Orsten not found on lyricsfreak
# Artist Steve Oliver not found on lyricsfreak
# Artist Sudan Archives not found on lyricsfreak
# Artist Merit Hemmingson not found on lyricsfreak
# Artist Ayhan Sicimoğlu not found on lyricsfreak
# Artist Metropolitan Jazz Affair not found on lyricsfreak
# Artist Ornette Coleman not found on lyricsfreak
# Artist Murcof not found on lyricsfreak
# Artist Tchavolo Schmitt not found on lyricsfreak
# Artist El Michels Affair not found on lyricsfreak
# Percentage Completion: 40.46442687747036% , Lyrics Obtained: 15849
# Now sleeping 30 seconds
# Artist Rick Braun not found on lyricsfreak
# Artist No Blues not found on lyricsfreak
# Artist Lennie Tristano not found on lyricsfreak
# Artist Ancient Astronauts not found on lyricsfreak
# Artist Akshin Alizadeh not found on lyricsfreak
# Artist Yaron Herman Trio not found on lyricsfreak
# Artist Jack DeJohnette not found on lyricsfreak
# Artist Trummor & Orgel not found on lyricsfreak
# Artist Reginald Omas Mamode IV not found on lyricsfreak
# Artist Thunderball not found on lyricsfreak
# Error for artist: Jack Jones
# Artist Quasimode not found on lyricsfreak
# Artist L.T.D. not found on lyricsfreak
# Artist Stéphane Grappelli not found on lyricsfreak
# Artist Josef Leimberg not found on lyricsfreak
# Artist Dzihan & Kamien not found on lyricsfreak
# Artist Smokey Joe & The Kid not found on lyricsfreak
# Percentage Completion: 41.452569169960476% , Lyrics Obtained: 16028
# Now sleeping 30 seconds
# Artist Backini not found on lyricsfreak
# Artist Ronnie Foster not found on lyricsfreak
# Artist Peter Bernstein not found on lyricsfreak
# Artist Polar Bear not found on lyricsfreak
# Artist Erkan Oğur not found on lyricsfreak
# Artist Leman Sam not found on lyricsfreak
# Artist Caligula's Horse not found on lyricsfreak
# Artist Fleshquartet not found on lyricsfreak
# Artist Martin Taylor not found on lyricsfreak
# Artist Nels Cline not found on lyricsfreak
# Artist Gecko Turner not found on lyricsfreak
# Artist Philly Joe Jones not found on lyricsfreak
# Artist Animals As Leaders not found on lyricsfreak
# Percentage Completion: 42.440711462450594% , Lyrics Obtained: 16364
# Now sleeping 30 seconds
# Artist Club des Belugas not found on lyricsfreak
# Artist Arsenio Rodríguez not found on lyricsfreak
# Artist Sinne Eeg not found on lyricsfreak
# Artist Chris Potter not found on lyricsfreak
# Artist Cenk Erdoğan not found on lyricsfreak
# Artist Säkert! not found on lyricsfreak
# Artist R.L. Burnside not found on lyricsfreak
# Artist Keiko Matsui not found on lyricsfreak
# Artist Gong not found on lyricsfreak
# Artist Electric Wire Hustle not found on lyricsfreak
# Artist Zeki Müren not found on lyricsfreak
# Artist Sithu Aye not found on lyricsfreak
# Artist Chuck Loeb not found on lyricsfreak
# Artist Henri Texier not found on lyricsfreak
# Percentage Completion: 43.42885375494071% , Lyrics Obtained: 16658
# Now sleeping 30 seconds
# Artist Tok Tok Tok not found on lyricsfreak
# Artist Yellowjackets not found on lyricsfreak
# Artist Suzan Kardeş not found on lyricsfreak
# Artist Arch Echo not found on lyricsfreak
# Artist Elder Island not found on lyricsfreak
# Artist Eric Alexander not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/b/big+bill+broonzy/in+the+evenin_20286687.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/big+bill+broonzy/just+a+dream_20810421.html
# Artist Horace Silver not found on lyricsfreak
# Artist Ceylan Ertem not found on lyricsfreak
# Artist La-33 not found on lyricsfreak
# Artist Tony Levin not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/k/king+crimson/coda+i+have+a+dream_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/k/king+crimson/epitaphmarch+for+no+reasontomorrow+and+tomorrow_0.html
# Artist Conquering Dystopia not found on lyricsfreak
# Artist Jessy J not found on lyricsfreak
# Artist Matana Roberts not found on lyricsfreak
# Artist Medeski, Martin & Wood not found on lyricsfreak
# Percentage Completion: 44.41699604743083% , Lyrics Obtained: 16925
# Now sleeping 30 seconds
# Artist Richard Spaven not found on lyricsfreak
# Artist Domingo Quiñones not found on lyricsfreak
# Artist Shirley & Lee not found on lyricsfreak
# Artist Sylvain Luc not found on lyricsfreak
# Artist Chris Standring not found on lyricsfreak
# Artist Hüsnü Arkan not found on lyricsfreak
# Artist Lyre Le Temps not found on lyricsfreak
# Artist Tommy Emmanuel not found on lyricsfreak
# Artist Shakti not found on lyricsfreak
# Artist Kormac not found on lyricsfreak
# Artist Silk Rhodes not found on lyricsfreak
# Artist Clap! Clap! not found on lyricsfreak
# Artist Nicki Parrott not found on lyricsfreak
# Artist Portico Quartet not found on lyricsfreak
# Artist Miles Davis Quartet not found on lyricsfreak
# Percentage Completion: 45.405138339920946% , Lyrics Obtained: 17174
# Now sleeping 30 seconds
# Artist Beny Moré not found on lyricsfreak
# Artist Fattburger not found on lyricsfreak
# Artist Erin Boheme not found on lyricsfreak
# Artist Rafael Anton Irisarri not found on lyricsfreak
# Artist Elvin Jones not found on lyricsfreak
# Artist Hiroshima not found on lyricsfreak
# Artist Kneebody not found on lyricsfreak
# Artist Frida Hyvönen not found on lyricsfreak
# Artist Mercan Dede not found on lyricsfreak
# Artist Evan Brewer not found on lyricsfreak
# Artist Joe Lovano not found on lyricsfreak
# Artist James Moody not found on lyricsfreak
# Artist Ralph Towner not found on lyricsfreak
# Artist Hadouk Trio not found on lyricsfreak
# Percentage Completion: 46.39328063241107% , Lyrics Obtained: 17386
# Now sleeping 30 seconds
# Artist Danilo Perez not found on lyricsfreak
# Artist Degiheugi not found on lyricsfreak
# Artist Magnus Öström not found on lyricsfreak
# Artist McCoy Tyner not found on lyricsfreak
# Artist Shabaka and the Ancestors not found on lyricsfreak
# Artist Mike Moreno not found on lyricsfreak
# Artist Johnny Colon not found on lyricsfreak
# Artist Liquorworks not found on lyricsfreak
# Artist Mo' Horizons not found on lyricsfreak
# Artist Brenda Boykin not found on lyricsfreak
# Artist Jan Johansson not found on lyricsfreak
# Artist Dorado Schmitt not found on lyricsfreak
# Artist Oscar D'León not found on lyricsfreak
# Artist 1900 not found on lyricsfreak
# Percentage Completion: 47.38142292490119% , Lyrics Obtained: 17584
# Now sleeping 30 seconds
# Artist Scale The Summit not found on lyricsfreak
# Artist DJ Food not found on lyricsfreak
# Artist Tete Montoliu not found on lyricsfreak
# Artist Dave Holland not found on lyricsfreak
# Artist Dave Holland Quintet not found on lyricsfreak
# Artist Colin Stetson not found on lyricsfreak
# Artist Dimension Latina not found on lyricsfreak
# Artist Jakob Bro not found on lyricsfreak
# Artist Chick Webb not found on lyricsfreak
# Artist Mark Turner not found on lyricsfreak
# Artist Woody Herman & His Orchestra not found on lyricsfreak
# Artist Count Basie Big Band not found on lyricsfreak
# Artist Thelonious Monk Quintet not found on lyricsfreak
# ...
# Artist Michael Wollny not found on lyricsfreak
# Artist Clarence "Gatemouth" Brown not found on lyricsfreak
# Artist Stanley Jordan not found on lyricsfreak
# Artist Michael Brecker not found on lyricsfreak
# Artist Adam Baldych not found on lyricsfreak
# Artist Atjazz not found on lyricsfreak
# Artist Bugge Wesseltoft not found on lyricsfreak
# Artist George Howard not found on lyricsfreak
# Artist Karriem Riggins not found on lyricsfreak
# Artist Rae & Christian not found on lyricsfreak
# Percentage Completion: 79.9901185770751% , Lyrics Obtained: 26622
# Now sleeping 30 seconds
# Artist Wes Montgomery Trio not found on lyricsfreak
# Artist The Ocean not found on lyricsfreak
# Artist Danilo Rea not found on lyricsfreak
# Artist Nuspirit Helsinki not found on lyricsfreak
# Artist Angel Canales not found on lyricsfreak
# Artist Henry Fiol not found on lyricsfreak
# Artist Richard Dorfmeister not found on lyricsfreak
# Artist Rodney Hunter not found on lyricsfreak
# Artist Trüby Trio not found on lyricsfreak
# Artist Hieroglyphic Being not found on lyricsfreak
# Artist Hot Sugar Band not found on lyricsfreak
# Artist Cory Henry not found on lyricsfreak
# Artist Benny Golson not found on lyricsfreak
# Artist Hank Jones not found on lyricsfreak
# Artist Eric Reed not found on lyricsfreak
# Artist Bill Watrous not found on lyricsfreak
# Artist Dr. Lonnie Smith not found on lyricsfreak
# Artist Keyon Harrold not found on lyricsfreak
# Artist Kızılırmak not found on lyricsfreak
# Percentage Completion: 80.97826086956522% , Lyrics Obtained: 26650
# Now sleeping 30 seconds
# Artist Marcus Johnson not found on lyricsfreak
# Artist Richard Bona not found on lyricsfreak
# Artist Dimie Cat not found on lyricsfreak
# Artist Streetwize not found on lyricsfreak
# Artist Jeff Golub not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/s/spencer+day/skylark_0.html
# Artist Brian Bennett not found on lyricsfreak
# Artist Timo Lassy not found on lyricsfreak
# Artist Harvey Mason not found on lyricsfreak
# Artist The Coasters not found on lyricsfreak
# Artist Lee Konitz not found on lyricsfreak
# Artist Chris Dave and The Drumhedz not found on lyricsfreak
# Artist Tal Wilkenfeld not found on lyricsfreak
# Artist Jazztronik not found on lyricsfreak
# Artist Kraak & Smaak not found on lyricsfreak
# Artist Magic Slim not found on lyricsfreak
# Artist Moğollar not found on lyricsfreak
# Percentage Completion: 81.96640316205534% , Lyrics Obtained: 26753
# Now sleeping 30 seconds
# Artist James Tillman not found on lyricsfreak
# Artist Amason not found on lyricsfreak
# Artist Guts not found on lyricsfreak
# Artist 123 not found on lyricsfreak
# Artist Biréli Lagrène not found on lyricsfreak
# Artist Matthew Halsall not found on lyricsfreak
# Artist T-Bone Walker not found on lyricsfreak
# Artist Gevende not found on lyricsfreak
# Artist Drewsif Stalin's Musical Endeavors not found on lyricsfreak
# Artist Mary Halvorson not found on lyricsfreak
# Artist Kenny Clarke not found on lyricsfreak
# Artist Neşet Ertaş not found on lyricsfreak
# Percentage Completion: 82.95454545454545% , Lyrics Obtained: 27348
# Now sleeping 30 seconds
# Artist Bembeya Jazz National not found on lyricsfreak
# Artist Dexter Wansel not found on lyricsfreak
# Artist Romane not found on lyricsfreak
# Artist SFJazz Collective not found on lyricsfreak
# Artist Sean Jones not found on lyricsfreak
# Artist Müzeyyen Senar not found on lyricsfreak
# Artist Hiromi not found on lyricsfreak
# Artist Potatohead People not found on lyricsfreak
# Artist Thad Jones not found on lyricsfreak
# Artist Luis "Perico" Ortiz not found on lyricsfreak
# Artist Andrea Motis not found on lyricsfreak
# Percentage Completion: 83.94268774703558% , Lyrics Obtained: 27667
# Now sleeping 30 seconds
# Artist Joseph Alessi not found on lyricsfreak
# Artist Orquesta La Conspiración not found on lyricsfreak
# Artist Louie Ramirez not found on lyricsfreak
# Artist Los Van Van not found on lyricsfreak
# Artist Randy Brecker not found on lyricsfreak
# Artist Christian McBride not found on lyricsfreak
# Artist Machito not found on lyricsfreak
# Artist Aynur not found on lyricsfreak
# Artist TKZEE not found on lyricsfreak
# Artist Sleep Walker not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/b/brian+auger/a+day+in+the+life_0.html
# Artist Jim Hall not found on lyricsfreak
# Artist Tall Black Guy not found on lyricsfreak
# Artist The Seshen not found on lyricsfreak
# Percentage Completion: 84.93083003952569% , Lyrics Obtained: 27825
# Now sleeping 30 seconds
# Artist Henry Wu not found on lyricsfreak
# Artist Eddie Palmieri not found on lyricsfreak
# Error for artist: Billy Strayhorn
# Artist Cyrus Chestnut not found on lyricsfreak
# Artist Screamin' Jay Hawkins not found on lyricsfreak
# Artist Philip Catherine not found on lyricsfreak
# Artist Michael Manring not found on lyricsfreak
# Artist Yazz Ahmed not found on lyricsfreak
# Artist Nubiyan Twist not found on lyricsfreak
# Artist Gaye Su Akyol not found on lyricsfreak
# Artist Kenny Wheeler not found on lyricsfreak
# Artist Mndsgn not found on lyricsfreak
# Artist Corduroy not found on lyricsfreak
# Artist Photay not found on lyricsfreak
# Artist Devin Townsend Band not found on lyricsfreak
# Percentage Completion: 85.91897233201581% , Lyrics Obtained: 28003
# Now sleeping 30 seconds
# Artist Jackie McLean not found on lyricsfreak
# Artist Adani & Wolf not found on lyricsfreak
# Artist Bob Reynolds not found on lyricsfreak
# Artist Robert Lockwood, Jr. not found on lyricsfreak
# Artist Emancipator not found on lyricsfreak
# Artist King Oliver not found on lyricsfreak
# Artist Omar Sosa not found on lyricsfreak
# Artist Alegre All Stars not found on lyricsfreak
# Artist Chivirico Davila not found on lyricsfreak
# Error for artist: Johnny Mathis
# Artist Bill Laurance not found on lyricsfreak
# Artist Mocky not found on lyricsfreak
# Artist Jon Hassell not found on lyricsfreak
# Artist Manu Katché not found on lyricsfreak
# Artist Joomanji not found on lyricsfreak
# Percentage Completion: 86.90711462450592% , Lyrics Obtained: 28312
# Now sleeping 30 seconds
# Artist Antonio Sánchez not found on lyricsfreak
# Artist Kognitif not found on lyricsfreak
# Artist AlgoRythmik not found on lyricsfreak
# Artist Natural Self not found on lyricsfreak
# Artist Térez Montcalm not found on lyricsfreak
# Artist Eberhard Weber not found on lyricsfreak
# Artist Al Dobson Jr. not found on lyricsfreak
# Artist Hector Plimmer not found on lyricsfreak
# Artist Sunnyland Slim not found on lyricsfreak
# Artist Eydie Gormé not found on lyricsfreak
# Artist Sam Rivers not found on lyricsfreak
# Artist Chad Wackerman not found on lyricsfreak
# Percentage Completion: 87.89525691699605% , Lyrics Obtained: 28509
# Now sleeping 30 seconds
# Lyrics restricted for URL https://www.lyricsfreak.com/e/etta+james/take+it+to+the+limit_20805980.html
# Artist Tord Gustavsen Trio not found on lyricsfreak
# Artist Pat Metheny Group not found on lyricsfreak
# Artist Pat Metheny Trio not found on lyricsfreak
# Artist The Marvelettes not found on lyricsfreak
# Artist Slim Gaillard not found on lyricsfreak
# Artist Biosphere not found on lyricsfreak
# Artist Llorca not found on lyricsfreak
# Artist Tim Hecker not found on lyricsfreak
# Artist Hildur Guðnadóttir not found on lyricsfreak
# Artist Mike Stern not found on lyricsfreak
# Artist Selda Bağcan not found on lyricsfreak
# Percentage Completion: 88.88339920948617% , Lyrics Obtained: 29110
# Now sleeping 30 seconds
# Artist Bersarin Quartett not found on lyricsfreak
# Artist Esbjörn Svensson not found on lyricsfreak
# Artist Earthside not found on lyricsfreak
# Artist Derek Sherinian not found on lyricsfreak
# Artist DJ Kawasaki not found on lyricsfreak
# Artist J.B. Lenoir not found on lyricsfreak
# Artist Kenny Drew not found on lyricsfreak
# Artist Jeff Berlin not found on lyricsfreak
# Artist Fennesz not found on lyricsfreak
# Artist Selim Sesler not found on lyricsfreak
# Artist Cihat Aşkın not found on lyricsfreak
# Artist Los Hacheros not found on lyricsfreak
# Artist Frank Vignola not found on lyricsfreak
# Artist Slowgold not found on lyricsfreak
# Percentage Completion: 89.87154150197628% , Lyrics Obtained: 29334
# Now sleeping 30 seconds
# Artist Stefano Di Battista not found on lyricsfreak
# Artist Nickodemus not found on lyricsfreak
# Artist Quantic not found on lyricsfreak
# Artist toconoma not found on lyricsfreak
# Artist Milt Jackson not found on lyricsfreak
# Artist Phronesis not found on lyricsfreak
# Artist Swarvy not found on lyricsfreak
# Artist Wayne Snow not found on lyricsfreak
# Artist Pepper Adams not found on lyricsfreak
# Artist Benjamin Dube not found on lyricsfreak
# Artist Münir Nurettin Selçuk not found on lyricsfreak
# Artist Sabahat Akkiraz not found on lyricsfreak
# Artist Barbarito Torres not found on lyricsfreak
# Percentage Completion: 90.8596837944664% , Lyrics Obtained: 29505
# Now sleeping 30 seconds
# Artist Al Di Meola not found on lyricsfreak
# Artist Laura Misch not found on lyricsfreak
# Artist RAM RIDER not found on lyricsfreak
# Artist Johnny Griffin not found on lyricsfreak
# Artist Ismael Quintana not found on lyricsfreak
# Artist Lars Danielsson not found on lyricsfreak
# Artist Sonny Sharrock not found on lyricsfreak
# Artist Gordian Knot not found on lyricsfreak
# Artist DJ Cam Quartet not found on lyricsfreak
# Artist Mark Rae not found on lyricsfreak
# Artist Sex Mob not found on lyricsfreak
# Artist Orient Expressions not found on lyricsfreak
# Artist Harvey Sutherland not found on lyricsfreak
# Artist Sammy Davis Jr. not found on lyricsfreak
# Artist José James not found on lyricsfreak
# Percentage Completion: 91.84782608695652% , Lyrics Obtained: 29631
# Now sleeping 30 seconds
# Artist Eric Vloeimans not found on lyricsfreak
# Artist Pete Fountain not found on lyricsfreak
# Artist Ilhan Ersahin not found on lyricsfreak
# Artist Neil Cowley Trio not found on lyricsfreak
# Artist Keb' Mo' not found on lyricsfreak
# Artist Roberta Gambarini not found on lyricsfreak
# Artist Sister Rosetta Tharpe not found on lyricsfreak
# Artist Yussef Kamaal not found on lyricsfreak
# Artist Bernard "Pretty" Purdie not found on lyricsfreak
# Artist Nils Landgren not found on lyricsfreak
# Artist Bo Carter not found on lyricsfreak
# Artist Evan Marien not found on lyricsfreak
# Percentage Completion: 92.83596837944664% , Lyrics Obtained: 29873
# Now sleeping 30 seconds
# Error for artist: Stan Kenton
# Artist Anita O'Day not found on lyricsfreak
# Artist Jim Tomlinson not found on lyricsfreak
# Artist Barrio Jazz Gang not found on lyricsfreak
# Artist Mehmet Erdem not found on lyricsfreak
# Artist Billy Cobham not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/b/bessie+smith/if+you+dont+i+know+who+will_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/bessie+smith/kitchen+man_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/bessie+smith/need+a+little+sugar+in+my+bowl_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/bessie+smith/st+louis+blues+soundtrack+band+introcrap+gamecst_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/bessie+smith/whats+the+matter+now_0.html
# Lyrics restricted for URL https://www.lyricsfreak.com/b/bessie+smith/yes+indeed+he+do_0.html
# Artist Orlando "Cachaíto" López not found on lyricsfreak
# Artist Isabella Lundgren not found on lyricsfreak
# Artist Mehmet Güreli not found on lyricsfreak
# Artist Dakota Staton not found on lyricsfreak
# Lyrics restricted for URL https://www.lyricsfreak.com/b/basia/until+you+come+back+to+me_20277996.html
# Artist Shai Maestro not found on lyricsfreak
# Artist Paul Bley not found on lyricsfreak
# Artist Los Guaracheros De Oriente not found on lyricsfreak
# Percentage Completion: 93.82411067193677% , Lyrics Obtained: 30182
# Now sleeping 30 seconds
# Artist The Necks not found on lyricsfreak
# Artist Victor Bailey not found on lyricsfreak
# Artist Steve Hillage not found on lyricsfreak
# Artist Richard "Groove" Holmes not found on lyricsfreak
# Artist Alphonse Mouzon not found on lyricsfreak
# Artist T.R.A.M not found on lyricsfreak
# Artist Joey DeFrancesco not found on lyricsfreak
# Artist Musica Nuda not found on lyricsfreak
# Artist Sam Levine not found on lyricsfreak
# Artist Amenra not found on lyricsfreak
# Artist Soen not found on lyricsfreak
# Artist Larry Coryell not found on lyricsfreak
# Percentage Completion: 94.81225296442688% , Lyrics Obtained: 30454
# Now sleeping 30 seconds
# Artist Wolfgang Muthspiel not found on lyricsfreak
# Artist Binker and Moses not found on lyricsfreak
# Artist Eddie Henderson not found on lyricsfreak
# Artist letherette not found on lyricsfreak
# Artist Omara Portuondo not found on lyricsfreak
# Artist Jimmy Giuffre not found on lyricsfreak
# Artist Nat Adderley not found on lyricsfreak
# Artist Roy Hargrove not found on lyricsfreak
# Artist Sonny Stitt not found on lyricsfreak
# Artist The Meters not found on lyricsfreak
# Artist Skeewiff not found on lyricsfreak
# Artist Duke Pearson not found on lyricsfreak
# Artist Jan Garbarek not found on lyricsfreak
# Artist General Elektriks not found on lyricsfreak
# Artist Owane not found on lyricsfreak
# Artist Allan Holdsworth not found on lyricsfreak
# Artist Swingrowers not found on lyricsfreak
# Percentage Completion: 95.800395256917% , Lyrics Obtained: 30563
# Now sleeping 30 seconds
# Artist Eric Harland not found on lyricsfreak
# Artist Lage Lund not found on lyricsfreak
# Artist DJ Harrison not found on lyricsfreak
# Artist Donny McCaslin not found on lyricsfreak
# Artist Sun Ra Arkestra not found on lyricsfreak
# Artist Johnny Otis not found on lyricsfreak
# Artist Naná Vasconcelos not found on lyricsfreak
# Artist Andrew Ashong not found on lyricsfreak
# Artist Rasmus Faber not found on lyricsfreak
# Artist Otis Spann not found on lyricsfreak
# Artist Phil Woods not found on lyricsfreak
# Artist Kevin Toney not found on lyricsfreak
# Artist Barbara Dennerlein not found on lyricsfreak
# Artist Kurt Rosenwinkel not found on lyricsfreak
# Artist ¡Cubanismo! not found on lyricsfreak
# Percentage Completion: 96.78853754940711% , Lyrics Obtained: 30715
# Now sleeping 30 seconds
# Artist Panzerballett not found on lyricsfreak
# Artist Souleance not found on lyricsfreak
# Artist Azymuth not found on lyricsfreak
# Artist Charlie Christian not found on lyricsfreak
# Artist Terje Rypdal not found on lyricsfreak
# Artist Ex Eye not found on lyricsfreak
# Artist Jestofunk not found on lyricsfreak
# Artist Jim Adkins not found on lyricsfreak
# Artist Dave Valentin not found on lyricsfreak
# Artist Nova Collective not found on lyricsfreak
# Artist Louie Austen not found on lyricsfreak
# Artist Paul Motian not found on lyricsfreak
# Artist Omer Klein not found on lyricsfreak
# Artist Moses Boyd not found on lyricsfreak
# Artist Abraham Laboriel not found on lyricsfreak
# Percentage Completion: 97.77667984189723% , Lyrics Obtained: 30855
# Now sleeping 30 seconds
# Artist Roy Eldridge not found on lyricsfreak
# Artist Benny Carter not found on lyricsfreak
# Artist Susso not found on lyricsfreak
# Artist United Future Organization not found on lyricsfreak
# Artist Flevans not found on lyricsfreak
# Artist Polarization not found on lyricsfreak
# Artist Eric Dolphy not found on lyricsfreak
# Artist Lawrence English not found on lyricsfreak
# Artist Behold... The Arctopus not found on lyricsfreak
# Artist Romare not found on lyricsfreak
# Artist Lazy Lester not found on lyricsfreak
# Percentage Completion: 98.76482213438736% , Lyrics Obtained: 31130
# Now sleeping 30 seconds
# Artist Kyoto Jazz Sextet not found on lyricsfreak
# Artist Malene Mortensen not found on lyricsfreak
# Artist Dominic Miller not found on lyricsfreak
# Artist Gabino Pampini not found on lyricsfreak
# Artist Oren Ambarchi not found on lyricsfreak
# Artist Call Super not found on lyricsfreak
# Artist Tommy Olivencia not found on lyricsfreak
# Artist Vusi Mahlasela not found on lyricsfreak
# Artist H ZETTRIO not found on lyricsfreak
# Artist Duke Jordan not found on lyricsfreak
# Artist Yavuz Çetin not found on lyricsfreak
# Artist Allan Edwall not found on lyricsfreak
# Artist Branford Marsalis not found on lyricsfreak
# Percentage Completion: 99.75296442687747% , Lyrics Obtained: 31217
# Now sleeping 30 seconds
# Artist Susan Wong not found on lyricsfreak
# Artist Emily Remler not found on lyricsfreak
# Artist Norrda not found on lyricsfreak
# Artist Jojje Wadenius not found on lyricsfreak

# %%
lyrics_jazz3_df = pd.read_csv('../kaggleDataset/lyrics_jazz3.csv')
langs = get_list_langs(lyrics_jazz3_df)
# Out:
# Completion: 0.031984376000512266
# Completion: 0.06400076839341742
# Completion: 0.0960171607863226
# Completion: 0.12803355317922777
# Completion: 0.16004994557213292
# Completion: 0.1920663379650381
# Completion: 0.22408273035794327
# Completion: 0.25609912275084845
# Completion: 0.2881155151437536
# Completion: 0.32013190753665877
# Completion: 0.3521482999295639
# Completion: 0.3841646923224691
# Completion: 0.4161810847153743
# Completion: 0.44819747710827945
# Completion: 0.4802138695011846
# Completion: 0.5122302618940898
# Completion: 0.5442466542869949
# Completion: 0.5762630466799001
# Completion: 0.6082794390728052
# Completion: 0.6402958314657105
# Completion: 0.6723122238586157
# Completion: 0.7043286162515208
# Completion: 0.736345008644426
# Completion: 0.7683614010373311
# Completion: 0.8003777934302363
# Completion: 0.8323941858231414
# Completion: 0.8644105782160466
# Completion: 0.8964269706089518
# Completion: 0.9284433630018569
# Completion: 0.9604597553947621
# Completion: 0.9924761477876672

# %%
lyrics_jazz3_df['language'] = langs
english_jazz3_df = lyrics_jazz3_df[lyrics_jazz3_df['language'] == 'en']
english_jazz3_df.drop_duplicates(['song', 'artist'], inplace = True)
print("Number of lyrics in English: {}".format(len(english_jazz3_df)))
print("Number of lyrics in other language: {}".format(len(lyrics_jazz3_df) - len(english_jazz3_df)))
english_jazz3_df.head()
# Out:
# Number of lyrics in English: 29802
# Number of lyrics in other language: 1432
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              song  year     artist genre  \
# 0          A Change Is Gonna Come   NaN  Sam Cooke  jazz
# 1             A Whole Lotta Woman   NaN  Sam Cooke  jazz
# 2               A Wonderful World   NaN  Sam Cooke  jazz
# 3               Ain't Misbehavin'   NaN  Sam Cooke  jazz
# 4  Ain't Nobody's Bizness If I Do   NaN  Sam Cooke  jazz
#
#                                               lyrics language
# 0  I was born by the river in a little tent. Oh a...       en
# 1  I've got a rocking chair that rocks, a rubber ...       en
# 2  Name        Wonderful World. Interpret   Sam C...       en
# 3  No one to walk with, all by myself. No one to ...       en
# 4  There ain't nothing I can do. Or nothing I can...       en

# %%
english_jazz3_df.to_csv("../kaggleDataset/lyrics_jazz3.csv", index = False)

# %%
jazz_df3 = pd.read_csv('../kaggleDataset/lyrics_jazz3.csv')
jazz_df2 = pd.read_csv('../kaggleDataset/lyrics_jazz2.csv')
jazz_df = pd.read_csv('../kaggleDataset/lyrics_jazz.csv')

lyrics_df = pd.read_csv('../kaggleDataset/lyrics_full_augmented.csv')

lyrics_df[lyrics_df['genre'] == 'jazz'].head()
# Out:
#                               song    year                 artist genre  \
# 484                tennessee-blues  1972.0          bobby-charles  jazz
# 485                small-town-talk  1972.0          bobby-charles  jazz
# 486                  save-me-jesus  1972.0          bobby-charles  jazz
# 487  i-must-be-in-a-good-place-now  1972.0          bobby-charles  jazz
# 762            so-glad-you-re-mine  1994.0  arthur-big-boy-crudup  jazz
#
#                                                 lyrics language
# 484  If I've had my way I'd leave here today I'd le...       en
# 485  It's only small town talk\r\r\nYou know how pe...       en
# 486  They got sisters and brothers,\r\r\nfighting a...       en
# 487  Wild apple trees blooming all around\r\r\nI mu...       en
# 762  My baby's long and tall,\r\r\nShe's like a can...       en

# %%
def good_format_df(df):
    # Rename columns and make data similar to the original dataframe: lyric_df
    df.rename(columns = {'title': 'song', 'lang': 'language'}, inplace = True)
    print(df.columns)
    df['year'] = [None] * len(df)
    df['artist'] = [artist_name.lower().replace(' ', '-') for artist_name in df['artist']]
    df['song'] = [str(song_name).lower().replace(' ', '-').replace("'", '-') for song_name in df['song']]
    return df

lyrs_df = lyrics_df[lyrics_df['genre'] == 'jazz']

jazz_df_clean = good_format_df(jazz_df)
jazz_df_clean2 = good_format_df(jazz_df2)
jazz_df_clean3 = good_format_df(jazz_df3)

tot_jazz_df = pd.concat([lyrs_df, jazz_df_clean, jazz_df_clean2, jazz_df_clean3])
print("Total amount of jazz lyrics: {}".format(len(tot_jazz_df)))
tot_jazz_df = tot_df.drop_duplicates(['song', 'artist', 'genre'])
print("Total amount of jazz lyrics without duplicates: {}".format(len(tot_jazz_df)))
# Out:
# Index(['song', 'artist', 'genre', 'lyrics', 'language', 'year'], dtype='object')
# Index(['song', 'artist', 'genre', 'lyrics', 'language', 'year'], dtype='object')
# Index(['song', 'year', 'artist', 'genre', 'lyrics', 'language'], dtype='object')
# Total amount of jazz lyrics: 50642
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   app.launch_new_instance()
# Total amount of jazz lyrics without duplicates: 306777

# %%
# Adding the metal songs that were fetched:
metal_df = pd.read_csv('../kaggleDataset/lyrics_metal.csv')
print(len(metal_df))
metal_df_clean = good_format_df(metal_df)

tot_df = pd.concat([lyrics_df, metal_df_clean, jazz_df_clean, jazz_df_clean2, jazz_df_clean3])
print(print("Total amount of lyrics: {}".format(len(tot_df))))
# Drop duplicate lyrics: same name, artist and genre
tot_df.drop_duplicates(['song', 'artist', 'genre'], inplace = True)
print("Total amount of metal lyrics without duplicates: {}".format(len(tot_df)))
# Out:
# 1523
# Index(['song', 'artist', 'genre', 'lyrics', 'language'], dtype='object')
# Total amount of lyrics: 316547
# None
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# Total amount of metal lyrics without duplicates: 306777

# %%
# Save in csv file:
#tot_df.to_csv("../kaggleDataset/lyrics_final_oli.csv", index = False)

# %%
oli_df = pd.read_csv('../kaggleDataset/lyrics_final_oli.csv')
emma_df = pd.read_csv('../kaggleDataset/lyrics_final_emma.csv')
emma_df['language'] = ['en'] * len(emma_df)
emma_df['year'] = [None] * len(emma_df)

# %%
# Combien with emma file:
emma_df_clean = good_format_df(emma_df)

tot_df = pd.concat([oli_df, emma_df_clean])
tot_df = tot_df[tot_df['genre'] != 'hip-hop']
print(print("Total amount of lyrics: {}".format(len(tot_df))))

# Drop duplicate lyrics: same name, artist and genre
tot_df.drop_duplicates(['song', 'artist', 'genre'], inplace = True)
tot_df.drop_duplicates(['lyrics'], inplace = True)
print("Total amount of lyrics without duplicates: {}".format(len(tot_df)))
# Out:
# Index(['artist', 'genre', 'lyrics', 'song', 'language', 'year'], dtype='object')
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   after removing the cwd from sys.path.
# Total amount of lyrics: 603316
# None
# Total amount of lyrics without duplicates: 315254

# %%
tot_df.to_csv("../kaggleDataset/lyrics_final.csv", index = False)
