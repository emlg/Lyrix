# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import sys
import codecs
from ast import literal_eval
from sklearn.model_selection import train_test_split
from fasttext_preprocessing.fasttext_preprocessing import *

# %% [markdown]
# In this part we will build the neural network allowing us to do text prediction on the lyrics depending of the genre. First we will visualize the amount of lyrics that we have for each genre:

# %%
lyrics_df = pd.read_csv('../kaggleDataset/lyrics_final_clean_noQuotes.csv')
#MAIN_GENRES = {'pop', 'rock', 'metal', 'country', 'jazz', 'hip hop'}
# For now just work on pop and rock genres
MAIN_GENRES = {'pop', 'rock'}
print(len(lyrics_df))
lyrics_df.head(10)
# Out:
# 317015
#             artist genre language  \
# 0  beyonce-knowles   pop       en
# 1  beyonce-knowles   pop       en
# 2  beyonce-knowles   pop       en
# 3  beyonce-knowles   pop       en
# 4  beyonce-knowles   pop       en
# 5  beyonce-knowles   pop       en
# 6  beyonce-knowles   pop       en
# 7  beyonce-knowles   pop       en
# 8  beyonce-knowles   pop       en
# 9  beyonce-knowles   pop       en
#
#                                               lyrics                    song  \
# 0  oh baby how you doing\nyou know i m gonna cut ...               ego-remix
# 1  playin  everything so easy\nit s like you seem...            then-tell-me
# 2  if you search\nfor tenderness\nit isn t hard t...                 honesty
# 3  oh oh oh i oh oh oh i\n\nif i wrote a book abo...         you-are-my-rock
# 4  party the people the people the party it s pop...           black-culture
# 5  i heard\nchurch bells ringing\ni heard\na choi...  all-i-could-do-was-cry
# 6  this is just another day that i would spend\nw...      once-in-a-lifetime
# 7  waiting waiting waiting waiting\nwaiting waiti...                 waiting
# 8  \ni read all of the magazines\nwhile waiting a...               slow-love
# 9  nnnow honey\nyou better sit down and look arou...   why-don-t-you-love-me
#
#      year
# 0  2009.0
# 1  2009.0
# 2  2009.0
# 3  2009.0
# 4  2009.0
# 5  2009.0
# 6  2009.0
# 7  2009.0
# 8  2009.0
# 9  2009.0

# %%
n, bins, patches = plt.hist(x = list(lyrics_df["genre"]), bins=np.arange(0,len(set(lyrics_df["genre"])) + 1), color='orange', align = 'left', alpha=0.7, rwidth=0.5)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Genres')
plt.ylabel('Number of lyrics')
plt.title('Number of lyrics with the specific genre')
plt.xticks(rotation=60)
plt.show()

# %%
genre_lyrics_dict = {}
for genre in MAIN_GENRES:
    nbr_lyrics = len(lyrics_df[lyrics_df['genre'] == genre])
    genre_lyrics_dict[genre] = nbr_lyrics
    
MIN_NBR = min(genre_lyrics_dict.values())
print(MIN_NBR)
genre_lyrics_dict
# Out:
# 59850
# {'pop': 59850, 'rock': 94938}

# %% [markdown]
# Keep only genres of interest with as many number of songs in each genre: the min of lyrics in all the main genres

# %%
lyrics_main_df = lyrics_df[lyrics_df['genre'].isin(list(MAIN_GENRES))]
genre_song_dict = {}
train_indices = []
test_indices = []

for genre in MAIN_GENRES:
    songs_indices = lyrics_main_df[lyrics_main_df['genre'] == genre].index.tolist()
    # Get random lyrics elements:
    random_indices = random.sample(songs_indices, MIN_NBR)
    genre_song_dict[genre] = random_indices
    
    # Split in train and test sets
    train, test = train_test_split(random_indices, test_size = 0.1)
    train_indices += train
    test_indices += test
    
print(len(train_indices), len(test_indices))
# Out:
# 107730 11970

# %% [markdown]
# Import the dictionnaries of word embeddings:

# %%
# Load embeddings
file_vec = 'fasttext_preprocessing/model_lyrics3.vec'
file_bin = 'fasttext_preprocessing/model_lyrics3.bin'
fasttext_exe = 'fasttext_preprocessing/fasttext'

def load_embeddings(file_name):
    """
    Load the embeddings from the .vec file given as input
    """
    with codecs.open(file_name, 'r', 'utf-8') as f_in:
        lines = f_in.readlines()
        lines = lines[1:]
        vocabulary, wv = zip(*[line.strip().split(' ', 1) for line in lines])
    wv = np.loadtxt(wv)
    return wv, vocabulary

def get_embedding_for_missing_word(w):
    """
    Given a word as input, computes it's fasttext vector using the file_bin file
    """
    data = ! echo $w | $fasttext_exe print-word-vectors $file_bin
    emb = np.zeros(100)
    for i, x in enumerate(data[0].split( )[1:]):
        try:
            emb[i] = float(x)
        except ValueError:
            print(data[0])
    return emb

word_embeddings, vocabulary = load_embeddings(file_vec)

# %%
# Create dictionaries
voc_embeds_dict = {}
embeds_voc_dict = {}

for voc, embed in zip(vocabulary, word_embeddings):
    voc_embeds_dict[voc] = tuple(embed)
    embeds_voc_dict[tuple(embed)] = voc
    
dict_length_init = len(voc_embeds_dict.keys())
print(dict_length_init)
# Out:
# 88213

# %% [markdown]
# Search for all the words in the lyrics that are not in the embeddings:

# %%
# THIS CELL TAKES LONG TIME TO RUN
def find_missing_words(lyrics, vocab):
    """
    Given lyrics of songs, find the words in it that are not in the vocabulary (word embeddings)
    """
    sentences = str(lyrics).replace('\n', ' ')
    list_words = sentences.split(' ')
    missing_words = set(list_words).difference(vocab)
    return missing_words


vocab = set(voc_embeds_dict.keys())
#missing_vocab = set()

for i, row in lyrics_df.iterrows():
    if i % 1000 == 999:
        print(float(i)/ len(lyrics_df))
    lyrics = row['lyrics']
    missing_words = find_missing_words(lyrics, vocab)
    
    missing_vocab = missing_vocab.union(missing_words)
    vocab = vocab.union(missing_words)
# Out:
# 0.0031512704446161853
# 0.0063056953141018566
# 0.009460120183587528
# 0.012614545053073198
# 0.01576896992255887
# 0.01892339479204454
# 0.02207781966153021
# 0.02523224453101588
# 0.028386669400501552
# 0.031541094269987226
# 0.03469551913947289
# 0.037849944008958566
# 0.04100436887844424
# 0.04415879374792991
# 0.04731321861741558
# 0.05046764348690125
# 0.05362206835638692
# 0.056776493225872596
# 0.05993091809535826
# 0.06308534296484393
# 0.06623976783432961
# 0.06939419270381528
# 0.07254861757330094
# 0.07570304244278662
# 0.07885746731227229
# 0.08201189218175796
# 0.08516631705124363
# 0.0883207419207293
# 0.09147516679021497
# 0.09462959165970064
# 0.09778401652918632
# 0.10093844139867199
# 0.10409286626815765
# 0.10724729113764334
# 0.110401716007129
# 0.11355614087661467
# 0.11671056574610034
# 0.11986499061558602
# 0.12301941548507168
# 0.12617384035455737
# 0.12932826522404303
# 0.1324826900935287
# 0.13563711496301437
# 0.13879153983250003
# 0.1419459647019857
# 0.1451003895714714
# 0.14825481444095706
# 0.15140923931044273
# 0.1545636641799284
# 0.15771808904941406
# 0.16087251391889973
# 0.1640269387883854
# 0.1671813636578711
# 0.17033578852735676
# 0.17349021339684242
# 0.1766446382663281
# 0.17979906313581376
# 0.18295348800529943
# 0.1861079128747851
# 0.1892623377442708
# 0.19241676261375645
# 0.19557118748324212
# 0.1987256123527278
# 0.20188003722221345
# 0.20503446209169912
# 0.20818888696118482
# 0.21134331183067048
# 0.21449773670015615
# 0.21765216156964182
# 0.22080658643912748
# 0.22396101130861315
# 0.22711543617809882
# 0.2302698610475845
# 0.23342428591707018
# 0.23657871078655585
# 0.2397331356560415
# 0.24288756052552718
# 0.24604198539501285
# 0.2491964102644985
# 0.2523508351339842
# 0.25550526000346985
# 0.25865968487295554
# 0.26181410974244124
# 0.2649685346119269
# 0.26812295948141257
# 0.2712773843508982
# 0.2744318092203839
# 0.27758623408986954
# 0.28074065895935524
# 0.28389508382884093
# 0.28704950869832657
# 0.29020393356781227
# 0.2933583584372979
# 0.2965127833067836
# 0.29966720817626924
# 0.30282163304575493
# 0.30597605791524063
# 0.30913048278472627
# 0.31228490765421196
# 0.3154393325236976
# 0.3185937573931833
# 0.32174818226266894
# 0.32490260713215463
# 0.3280570320016403
# 0.33121145687112596
# 0.33436588174061166
# 0.3375203066100973
# 0.340674731479583
# 0.34382915634906863
# 0.3469835812185543
# 0.35013800608804
# 0.35329243095752566
# 0.35644685582701136
# 0.359601280696497
# 0.3627557055659827
# 0.36591013043546833
# 0.369064555304954
# 0.3722189801744397
# 0.37537340504392536
# 0.37852782991341105
# 0.3816822547828967
# 0.3848366796523824
# 0.387991104521868
# 0.3911455293913537
# 0.3942999542608394
# 0.39745437913032505
# 0.40060880399981075
# 0.4037632288692964
# 0.4069176537387821
# 0.4100720786082677
# 0.4132265034777534
# 0.4163809283472391
# 0.41953535321672475
# 0.42268977808621044
# 0.4258442029556961
# 0.4289986278251818
# 0.43215305269466747
# 0.4353074775641531
# 0.4384619024336388
# 0.44161632730312445
# 0.44477075217261014
# 0.4479251770420958
# 0.4510796019115815
# 0.45423402678106717
# 0.4573884516505528
# 0.4605428765200385
# 0.46369730138952414
# 0.46685172625900984
# 0.4700061511284955
# 0.47316057599798117
# 0.47631500086746686
# 0.4794694257369525
# 0.4826238506064382
# 0.48577827547592384
# 0.48893270034540953
# 0.49208712521489517
# 0.49524155008438087
# 0.49839597495386656
# 0.5015503998233523
# 0.5047048246928378
# 0.5078592495623235
# 0.5110136744318092
# 0.5141680993012949
# 0.5173225241707806
# 0.5204769490402662
# 0.5236313739097519
# 0.5267857987792376
# 0.5299402236487233
# 0.5330946485182089
# 0.5362490733876946
# 0.5394034982571803
# 0.542557923126666
# 0.5457123479961516
# 0.5488667728656372
# 0.5520211977351229
# 0.5551756226046086
# 0.5583300474740943
# 0.56148447234358
# 0.5646388972130656
# 0.5677933220825513
# 0.570947746952037
# 0.5741021718215227
# 0.5772565966910083
# 0.580411021560494
# 0.5835654464299797
# 0.5867198712994653
# 0.589874296168951
# 0.5930287210384366
# 0.5961831459079223
# 0.599337570777408
# 0.6024919956468937
# 0.6056464205163794
# 0.608800845385865
# 0.6119552702553507
# 0.6151096951248364
# 0.6182641199943221
# 0.6214185448638077
# 0.6245729697332933
# 0.627727394602779
# 0.6308818194722647
# 0.6340362443417504
# 0.637190669211236
# 0.6403450940807217
# 0.6434995189502074
# 0.6466539438196931
# 0.6498083686891788
# 0.6529627935586644
# 0.6561172184281501
# 0.6592716432976358
# 0.6624260681671215
# 0.665580493036607
# 0.6687349179060927
# 0.6718893427755784
# 0.6750437676450641
# 0.6781981925145498
# 0.6813526173840354
# 0.6845070422535211
# 0.6876614671230068
# 0.6908158919924925
# 0.6939703168619782
# 0.6971247417314638
# 0.7002791666009495
# 0.7034335914704352
# 0.7065880163399209
# 0.7097424412094065
# 0.7128968660788921
# 0.7160512909483778
# 0.7192057158178635
# 0.7223601406873492
# 0.7255145655568348
# 0.7286689904263205
# 0.7318234152958062
# 0.7349778401652919
# 0.7381322650347776
# 0.7412866899042632
# 0.7444411147737489
# 0.7475955396432346
# 0.7507499645127202
# 0.7539043893822059
# 0.7570588142516915
# 0.7602132391211772
# 0.7633676639906629
# 0.7665220888601486
# 0.7696765137296342
# 0.7728309385991199
# 0.7759853634686056
# 0.7791397883380913
# 0.782294213207577
# 0.7854486380770626
# 0.7886030629465482
# 0.791757487816034
# 0.7949119126855196
# 0.7980663375550053
# 0.8012207624244909
# 0.8043751872939766
# 0.8075296121634623
# 0.810684037032948
# 0.8138384619024336
# 0.8169928867719193
# 0.820147311641405
# 0.8233017365108907
# 0.8264561613803764
# 0.829610586249862
# 0.8327650111193476
# 0.8359194359888333
# 0.839073860858319
# 0.8422282857278047
# 0.8453827105972903
# 0.848537135466776
# 0.8516915603362617
# 0.8548459852057474
# 0.858000410075233
# 0.8611548349447187
# 0.8643092598142044
# 0.8674636846836901
# 0.8706181095531758
# 0.8737725344226613
# 0.876926959292147
# 0.8800813841616327
# 0.8832358090311184
# 0.8863902339006041
# 0.8895446587700897
# 0.8926990836395754
# 0.8958535085090611
# 0.8990079333785468
# 0.9021623582480325
# 0.9053167831175181
# 0.9084712079870038
# 0.9116256328564895
# 0.9147800577259751
# 0.9179344825954607
# 0.9210889074649464
# 0.9242433323344321
# 0.9273977572039178
# 0.9305521820734035
# 0.9337066069428891
# 0.9368610318123748
# 0.9400154566818605
# 0.9431698815513462
# 0.9463243064208319
# 0.9494787312903175
# 0.9526331561598032
# 0.9557875810292888
# 0.9589420058987745
# 0.9620964307682601
# 0.9652508556377458
# 0.9684052805072315
# 0.9715597053767172
# 0.9747141302462029
# 0.9778685551156885
# 0.9810229799851742
# 0.9841774048546599
# 0.9873318297241456
# 0.9904862545936313
# 0.9936406794631168
# 0.9967951043326025
# 0.9999495292020882

# %%
missing_vocab_lst = [w.lower() for w in list(missing_vocab)]
# Remove duplicates
missing_vocab_lst = list(set(missing_vocab_lst))
print(len(missing_vocab_lst))
print(missing_vocab_lst[:50])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-721f44ed5ca1> in <module>
# ----> 1 missing_vocab_lst = [w.lower() for w in list(missing_vocab)]
#       2 # Remove duplicates
#       3 missing_vocab_lst = list(set(missing_vocab_lst))
#       4 print(len(missing_vocab_lst))
#       5 print(missing_vocab_lst[:50])
#
# NameError: name 'missing_vocab' is not defined

# %%
import csv

missing_words_file = 'fasttext_preprocessing/missing_words.csv'
# Save missing words
"""with open(missing_words_file, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in missing_vocab_lst:
        writer.writerow([val])"""
        
# Read missing words
with open(missing_words_file, 'r') as f:
    reader = csv.reader(f)
    missing_vocab_lst = [ls_word[0] for ls_word in list(reader)]
print(len(missing_vocab_lst))
# Out:
# 281204

# %% [markdown]
# We thought about searching for embeddings of the missing words, and store them in the dictionary (way too long).
# Most of the missing words are actual words with a bad ortograph: lots of them contain a same letter repeating lots of time (e.g. Wwwwwworld instead of world). Thus we use regex to map these words to their actual correct representation:

# %%
import re

vocab = set(voc_embeds_dict.keys())
bad_good_word_dict = {}
for i, w in enumerate(missing_vocab_lst):
    correct_w = re.sub(r'(.)\1{2,}', r'\1', w)
    if correct_w in vocab:
        bad_good_word_dict[w] = correct_w
print("Number of correct mapped words: {}".format(len(bad_good_word_dict)))
# Out:
# Number of correct mapped words: 48467

# %% [markdown]
# Now let's get the embeddings from each words of the lyrics as follows:
#     * If the word is in the voc_embeds_dict dictionary, fetch his embedding
#     * Else if the word is in the bad_good_word_dict, fetch the good word and his corresponding embedding in the voc_embeds_dict dictionary
#     * Else remove the word from the lyrics (we don't have his emnedding and it's too long to compute it)

# %%
def generate_embedding_for_lyrics(l):
    """
    Given lyrics of songs, compute the word embeddings vectors for the lyrics
    """
    sentences = l.split('\n')
    embedding = []
    words_not_found = 0
    
    for s in sentences:
        words = s.split(' ')
        #print(repr(words))
        for i, w in enumerate(words):
            if len(w) >0:
                no_embed = False
                if w in voc_embeds_dict.keys():
                    # Get embedding from dict
                    embed = voc_embeds_dict[w]
                elif w in bad_good_word_dict.keys():
                    # Get matching word
                    correct_w = bad_good_word_dict[w]
                    # Get embedding of matching word
                    embed = voc_embeds_dict[correct_w]
                else:
                    words_not_found += 1
                    no_embed = True
                    
                # Add 1 in the embedding vector if it is last word of sentence, 0 otherwise
                if no_embed == False:
                    if i == (len(words)-1):
                        vector = np.append(embed, 1)
                    else :
                        vector = np.append(embed, 0)
                    vector = np.append(w, vector)
                    embedding.append(vector)
                else:
                    if i == (len(words)-1) and len(embedding) > 0:
                        # If no embedding found and word is last of sentence, last found word is last one of phrase:
                        embedding[-1][-1] = 1
    return embedding

# %%
lyrics_embeddings = []

for i, row in lyrics_df.head(1000).iterrows():
    if (i % 1000) == 999:
        print(float(i) / len(lyrics_df))    
    lyrics = row['lyrics']
    embedding = generate_embedding_for_lyrics(str(lyrics))
    
    lyrics_embeddings.append(embedding)
# Out:
# 0.0031512704446161853

# %%
lyrics_embeddings_file = 'fasttext_preprocessing/lyrics_clean_embeddings.csv'
# Save missing words
with open(lyrics_embeddings_file, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    writer.writerows(lyrics_embeddings)
        
# Read missing words

"""with open(missing_words_file, 'r') as f:
    reader = csv.reader(f)
    missing_vocab_lst = [ls_word[0] for ls_word in list(reader)]
print(len(missing_vocab_lst))"""
# Out:
# "with open(missing_words_file, 'r') as f:\n    reader = csv.reader(f)\n    missing_vocab_lst = [ls_word[0] for ls_word in list(reader)]\nprint(len(missing_vocab_lst))"

# %% [markdown]
# Transform lyrics to good input for the neural network

# %%
def lyrics_to_list_words(lyrics, vocab):
    """
    Given lyrics of songs, keep only the words with the embeddings
    """
    sentences = str(lyrics).replace('\n', ' ') # Don't consider end of words
    list_words = sentences.split(' ')
    list_words_cleaned = []
    incorrect_count = 0
    
    for w in list_words:
        if w in voc_embeds_dict.keys():
            list_words_cleaned.append(w)
        elif w in bad_good_word_dict.keys():
            # Get matching word
            correct_w = bad_good_word_dict[w]
            list_words_cleaned.append(correct_w)
        else: 
            # Word with no embedding, don't take it
            incorrect_count += 1 
    return list_words_cleaned, incorrect_count

# %%
def get_list_words_from_df(df, vocab):
    lyrics_cleaned = []
    total_incorrect = 0

    for i, row in df.iterrows():    
        lyrics = row['lyrics']
        words_cleaned, c = lyrics_to_list_words(str(lyrics), vocab)
        total_incorrect += c
        lyrics_cleaned.append(words_cleaned)
    print("Average of incorrect words per song: {}".format(float(total_incorrect) / len(df)))
    return lyrics_cleaned

# %%
vocab = set(voc_embeds_dict.keys())
list_lyrics = get_list_words_from_df(lyrics_df, vocab)
# Out:
# Average of incorrect words per song: 7.216765768181316

# %%
vocab = set(voc_embeds_dict.keys())
df_pop = lyrics_df[lyrics_df['genre'] == 'pop']
print("Pop songs: {}".format(len(df_pop)))
list_lyrics_pop = get_list_words_from_df(df_pop, vocab)
# Out:
# Pop songs: 59850
# Average of incorrect words per song: 8.359181286549708

# %% [markdown]
# Check lengths of lyrics repartitions

# %%
def get_lyrics_above(list_lyrics, min_nbr_words = 30):
    lengths_lyrics = [len(l) for l in list_lyrics]
    print("Words per lyrics: Min: {}, Max: {}, Avg: {}".format(min(lengths_lyrics), max(lengths_lyrics), np.mean(lengths_lyrics)))

    # Keep lyrics with more than certain number of words
    list_lyrics_nomin = [l for l in list_lyrics if len(l) > min_nbr_words]
    print("Ratio lyrics kept: {}".format(len(list_lyrics_nomin) / len(list_lyrics)))
    return list_lyrics_nomin, lengths_lyrics

# %%
list_lyrs_pop, lengths_pop = get_lyrics_above(list_lyrics)
# Out:
# Words per lyrics: Min: 0, Max: 8269, Avg: 246.0178098828131
# Ratio lyrics kept: 0.9901266501585099

# %%
words = []
for l in list_lyrs_pop:
    for w in l:
        words.append(w)

# %%
len(set(words))
# Out:
# 84951

# %% [markdown]
# Tokenize the lyrics: map each distinct word to an integer and convert the list of lyrics to the corresponding list of indices

# %%
# Keras imports
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding

# %%
tokenizer = Tokenizer(num_words = len(vocab))
tokenizer.fit_on_texts(list_lyrs_pop)
sequences = tokenizer.texts_to_sequences(list_lyrs_pop)

# %% [markdown]
# Padding of lyrics: the maximum length (in words) of lyrics is given by the mean of all lengths + 2 times the std in lengths such that 95% of the lyrics are not truncated

# %%
max_length_pad = int(np.mean(lengths_pop) + 2 * np.std(lengths_pop)) 
sequences_pad = pad_sequences(sequences, maxlen = max_length_pad, padding = 'pre', truncating = 'post', value = 0)

# %% [markdown]
# Create n-grams of words for each lyrics (based on the pads as it takes less memory):
# For instance, with n = 3 and lyrics "oh baby i love you", we obtain: ["oh baby i", "baby i love", "i love you"]

# %%
a = np.array([1,2,3,4,5,6])
a[:7]
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
def n_gram_lyrics(n, padded_lyrs):
    n_gram_lyrs = []
    for i, _ in enumerate(padded_lyrs[:-n].tolist()):
        n_gram = padded_lyrs[i : i + n] # take the element and next n - 1 ones
        if np.sum(n_gram) != 0:
            n_gram_lyrs.append(n_gram)
    return n_gram_lyrs

n_gram_lyrics(4, sequences_pad[0])
# Out:
# [array([ 0,  0,  0, 47], dtype=int32),
#  array([ 0,  0, 47, 64], dtype=int32),
#  array([ 0, 47, 64, 77], dtype=int32),
#  array([47, 64, 77,  3], dtype=int32),
#  array([ 64,  77,   3, 497], dtype=int32),
#  array([ 77,   3, 497,   3], dtype=int32),
#  array([  3, 497,   3,  30], dtype=int32),
#  array([497,   3,  30,   1], dtype=int32),
#  array([ 3, 30,  1, 18], dtype=int32),
#  array([30,  1, 18, 83], dtype=int32),
#  array([  1,  18,  83, 518], dtype=int32),
#  array([ 18,  83, 518,  82], dtype=int32),
#  array([ 83, 518,  82,   4], dtype=int32),
#  array([518,  82,   4,   2], dtype=int32),
#  array([  82,    4,    2, 1245], dtype=int32),
#  array([   4,    2, 1245,  103], dtype=int32),
#  array([   2, 1245,  103,  832], dtype=int32),
#  array([1245,  103,  832,  137], dtype=int32),
#  array([103, 832, 137, 177], dtype=int32),
#  array([832, 137, 177,  28], dtype=int32),
#  array([137, 177,  28,   8], dtype=int32),
#  array([177,  28,   8, 238], dtype=int32),
#  array([ 28,   8, 238,   1], dtype=int32),
#  array([  8, 238,   1,  29], dtype=int32),
#  array([238,   1,  29,   4], dtype=int32),
#  array([  1,  29,   4, 111], dtype=int32),
#  array([ 29,   4, 111,  13], dtype=int32),
#  array([  4, 111,  13,   1], dtype=int32),
#  array([111,  13,   1,  51], dtype=int32),
#  array([  13,    1,   51, 2375], dtype=int32),
#  array([   1,   51, 2375,   21], dtype=int32),
#  array([  51, 2375,   21,    6], dtype=int32),
#  array([2375,   21,    6,  888], dtype=int32),
#  array([  21,    6,  888, 2482], dtype=int32),
#  array([   6,  888, 2482,    3], dtype=int32),
#  array([ 888, 2482,    3,   30], dtype=int32),
#  array([2482,    3,   30,   32], dtype=int32),
#  array([ 3, 30, 32,  9], dtype=int32),
#  array([30, 32,  9, 91], dtype=int32),
#  array([ 32,   9,  91, 888], dtype=int32),
#  array([  9,  91, 888, 153], dtype=int32),
#  array([ 91, 888, 153,   3], dtype=int32),
#  array([888, 153,   3,   3], dtype=int32),
#  array([153,   3,   3,  81], dtype=int32),
#  array([ 3,  3, 81,  8], dtype=int32),
#  array([ 3, 81,  8,  7], dtype=int32),
#  array([81,  8,  7,  9], dtype=int32),
#  array([ 8,  7,  9, 16], dtype=int32),
#  array([ 7,  9, 16, 64], dtype=int32),
#  array([ 9, 16, 64, 58], dtype=int32),
#  array([16, 64, 58,  9], dtype=int32),
#  array([64, 58,  9, 42], dtype=int32),
#  array([ 58,   9,  42, 206], dtype=int32),
#  array([  9,  42, 206,   3], dtype=int32),
#  array([ 42, 206,   3,  26], dtype=int32),
#  array([206,   3,  26,  11], dtype=int32),
#  array([ 3, 26, 11, 94], dtype=int32),
#  array([26, 11, 94,  4], dtype=int32),
#  array([ 11,  94,   4, 164], dtype=int32),
#  array([ 94,   4, 164, 146], dtype=int32),
#  array([  4, 164, 146, 321], dtype=int32),
#  array([164, 146, 321,  67], dtype=int32),
#  array([146, 321,  67,   3], dtype=int32),
#  array([321,  67,   3,  37], dtype=int32),
#  array([67,  3, 37,  2], dtype=int32),
#  array([   3,   37,    2, 1258], dtype=int32),
#  array([  37,    2, 1258,   21], dtype=int32),
#  array([   2, 1258,   21,  195], dtype=int32),
#  array([1258,   21,  195,   65], dtype=int32),
#  array([ 21, 195,  65,   3], dtype=int32),
#  array([195,  65,   3,   4], dtype=int32),
#  array([ 65,   3,   4, 191], dtype=int32),
#  array([  3,   4, 191,   8], dtype=int32),
#  array([  4, 191,   8,  77], dtype=int32),
#  array([191,   8,  77,   3], dtype=int32),
#  array([ 8, 77,  3, 81], dtype=int32),
#  array([77,  3, 81,  1], dtype=int32),
#  array([   3,   81,    1, 3321], dtype=int32),
#  array([  81,    1, 3321,  238], dtype=int32),
#  array([   1, 3321,  238,  937], dtype=int32),
#  array([3321,  238,  937,   13], dtype=int32),
#  array([238, 937,  13,   9], dtype=int32),
#  array([937,  13,   9,   6], dtype=int32),
#  array([ 13,   9,   6, 210], dtype=int32),
#  array([  9,   6, 210, 865], dtype=int32),
#  array([  6, 210, 865, 107], dtype=int32),
#  array([210, 865, 107, 119], dtype=int32),
#  array([865, 107, 119,   3], dtype=int32),
#  array([107, 119,   3,  40], dtype=int32),
#  array([119,   3,  40,   2], dtype=int32),
#  array([  3,  40,   2, 969], dtype=int32),
#  array([ 40,   2, 969,   4], dtype=int32),
#  array([  2, 969,   4,  10], dtype=int32),
#  array([969,   4,  10,  84], dtype=int32),
#  array([ 4, 10, 84, 28], dtype=int32),
#  array([10, 84, 28,  3], dtype=int32),
#  array([84, 28,  3, 88], dtype=int32),
#  array([28,  3, 88, 11], dtype=int32),
#  array([ 3, 88, 11, 83], dtype=int32),
#  array([88, 11, 83, 94], dtype=int32),
#  array([11, 83, 94,  7], dtype=int32),
#  array([83, 94,  7,  1], dtype=int32),
#  array([ 94,   7,   1, 110], dtype=int32),
#  array([  7,   1, 110, 762], dtype=int32),
#  array([  1, 110, 762,   3], dtype=int32),
#  array([110, 762,   3, 315], dtype=int32),
#  array([762,   3, 315,  34], dtype=int32),
#  array([  3, 315,  34,  10], dtype=int32),
#  array([315,  34,  10, 302], dtype=int32),
#  array([ 34,  10, 302,   5], dtype=int32),
#  array([ 10, 302,   5, 191], dtype=int32),
#  array([302,   5, 191,   8], dtype=int32),
#  array([   5,  191,    8, 1460], dtype=int32),
#  array([ 191,    8, 1460,    3], dtype=int32),
#  array([   8, 1460,    3,  260], dtype=int32),
#  array([1460,    3,  260,   11], dtype=int32),
#  array([  3, 260,  11,  30], dtype=int32),
#  array([260,  11,  30,  51], dtype=int32),
#  array([ 11,  30,  51, 186], dtype=int32),
#  array([ 30,  51, 186,  35], dtype=int32),
#  array([ 51, 186,  35,  94], dtype=int32),
#  array([186,  35,  94,  21], dtype=int32),
#  array([35, 94, 21,  8], dtype=int32),
#  array([94, 21,  8,  4], dtype=int32),
#  array([ 21,   8,   4, 363], dtype=int32),
#  array([  8,   4, 363,   7], dtype=int32),
#  array([  4, 363,   7,   9], dtype=int32),
#  array([363,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 210], dtype=int32),
#  array([  9, 104, 210,   7], dtype=int32),
#  array([104, 210,   7,   9], dtype=int32),
#  array([210,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 759], dtype=int32),
#  array([  9, 104, 759,   7], dtype=int32),
#  array([104, 759,   7,   9], dtype=int32),
#  array([759,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 408], dtype=int32),
#  array([  9, 104, 408,   7], dtype=int32),
#  array([104, 408,   7, 121], dtype=int32),
#  array([408,   7, 121,  11], dtype=int32),
#  array([   7,  121,   11, 1044], dtype=int32),
#  array([ 121,   11, 1044,    7], dtype=int32),
#  array([  11, 1044,    7,    9], dtype=int32),
#  array([1044,    7,    9,  104], dtype=int32),
#  array([  7,   9, 104, 157], dtype=int32),
#  array([  9, 104, 157,   7], dtype=int32),
#  array([104, 157,   7,   9], dtype=int32),
#  array([157,   7,   9, 104], dtype=int32),
#  array([   7,    9,  104, 1142], dtype=int32),
#  array([   9,  104, 1142,   57], dtype=int32),
#  array([ 104, 1142,   57,  261], dtype=int32),
#  array([1142,   57,  261,   29], dtype=int32),
#  array([ 57, 261,  29,  31], dtype=int32),
#  array([261,  29,  31,  67], dtype=int32),
#  array([29, 31, 67, 57], dtype=int32),
#  array([31, 67, 57, 23], dtype=int32),
#  array([67, 57, 23, 71], dtype=int32),
#  array([57, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34, 57], dtype=int32),
#  array([ 7, 34, 57, 40], dtype=int32),
#  array([34, 57, 40,  6], dtype=int32),
#  array([ 57,  40,   6, 210], dtype=int32),
#  array([  40,    6,  210, 2712], dtype=int32),
#  array([   6,  210, 2712,  461], dtype=int32),
#  array([ 210, 2712,  461,    6], dtype=int32),
#  array([2712,  461,    6, 5761], dtype=int32),
#  array([ 461,    6, 5761, 2712], dtype=int32),
#  array([   6, 5761, 2712,    1], dtype=int32),
#  array([5761, 2712,    1,   25], dtype=int32),
#  array([2712,    1,   25,  113], dtype=int32),
#  array([  1,  25, 113, 210], dtype=int32),
#  array([  25,  113,  210, 2712], dtype=int32),
#  array([ 113,  210, 2712,    7], dtype=int32),
#  array([ 210, 2712,    7,    9], dtype=int32),
#  array([2712,    7,    9,  104], dtype=int32),
#  array([  7,   9, 104, 157], dtype=int32),
#  array([  9, 104, 157,  57], dtype=int32),
#  array([104, 157,  57, 220], dtype=int32),
#  array([157,  57, 220,  29], dtype=int32),
#  array([ 57, 220,  29,  31], dtype=int32),
#  array([220,  29,  31,  67], dtype=int32),
#  array([29, 31, 67, 57], dtype=int32),
#  array([31, 67, 57, 23], dtype=int32),
#  array([67, 57, 23, 71], dtype=int32),
#  array([57, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([  71,    7,   34, 3069], dtype=int32),
#  array([   7,   34, 3069,    1], dtype=int32),
#  array([  34, 3069,    1,   18], dtype=int32),
#  array([3069,    1,   18, 3174], dtype=int32),
#  array([   1,   18, 3174,   82], dtype=int32),
#  array([  18, 3174,   82,   39], dtype=int32),
#  array([3174,   82,   39,    1], dtype=int32),
#  array([82, 39,  1, 26], dtype=int32),
#  array([39,  1, 26, 11], dtype=int32),
#  array([  1,  26,  11, 879], dtype=int32),
#  array([ 26,  11, 879,   3], dtype=int32),
#  array([ 11, 879,   3,  23], dtype=int32),
#  array([879,   3,  23, 165], dtype=int32),
#  array([  3,  23, 165,  27], dtype=int32),
#  array([ 23, 165,  27,   8], dtype=int32),
#  array([165,  27,   8,  97], dtype=int32),
#  array([27,  8, 97,  3], dtype=int32),
#  array([ 8, 97,  3, 93], dtype=int32),
#  array([97,  3, 93, 62], dtype=int32),
#  array([ 3, 93, 62,  2], dtype=int32),
#  array([ 93,  62,   2, 644], dtype=int32),
#  array([ 62,   2, 644, 103], dtype=int32),
#  array([  2, 644, 103, 164], dtype=int32),
#  array([644, 103, 164,   7], dtype=int32),
#  array([ 103,  164,    7, 8325], dtype=int32),
#  array([ 164,    7, 8325,    1], dtype=int32),
#  array([   7, 8325,    1,  164], dtype=int32),
#  array([8325,    1,  164,    7], dtype=int32),
#  array([   1,  164,    7, 6960], dtype=int32),
#  array([ 164,    7, 6960,    3], dtype=int32),
#  array([   7, 6960,    3, 1521], dtype=int32),
#  array([6960,    3, 1521,   36], dtype=int32),
#  array([   3, 1521,   36,    3], dtype=int32),
#  array([1521,   36,    3,  136], dtype=int32),
#  array([ 36,   3, 136,  16], dtype=int32),
#  array([  3, 136,  16,  32], dtype=int32),
#  array([136,  16,  32,   1], dtype=int32),
#  array([16, 32,  1, 18], dtype=int32),
#  array([ 32,   1,  18, 878], dtype=int32),
#  array([  1,  18, 878,  27], dtype=int32),
#  array([ 18, 878,  27, 456], dtype=int32),
#  array([878,  27, 456,   1], dtype=int32),
#  array([ 27, 456,   1,  30], dtype=int32),
#  array([456,   1,  30,   1], dtype=int32),
#  array([ 1, 30,  1, 18], dtype=int32),
#  array([ 30,   1,  18, 908], dtype=int32),
#  array([  1,  18, 908,   3], dtype=int32),
#  array([ 18, 908,   3,  27], dtype=int32),
#  array([908,   3,  27, 122], dtype=int32),
#  array([   3,   27,  122, 1320], dtype=int32),
#  array([  27,  122, 1320,  150], dtype=int32),
#  array([ 122, 1320,  150,  522], dtype=int32),
#  array([1320,  150,  522,  122], dtype=int32),
#  array([ 150,  522,  122, 3149], dtype=int32),
#  array([ 522,  122, 3149,  371], dtype=int32),
#  array([ 122, 3149,  371,    6], dtype=int32),
#  array([3149,  371,    6,  952], dtype=int32),
#  array([371,   6, 952,   7], dtype=int32),
#  array([  6, 952,   7,   9], dtype=int32),
#  array([952,   7,   9,  10], dtype=int32),
#  array([  7,   9,  10, 348], dtype=int32),
#  array([  9,  10, 348,  97], dtype=int32),
#  array([ 10, 348,  97, 267], dtype=int32),
#  array([348,  97, 267,  10], dtype=int32),
#  array([ 97, 267,  10, 124], dtype=int32),
#  array([267,  10, 124, 200], dtype=int32),
#  array([ 10, 124, 200,   3], dtype=int32),
#  array([124, 200,   3,   6], dtype=int32),
#  array([ 200,    3,    6, 5722], dtype=int32),
#  array([   3,    6, 5722,    4], dtype=int32),
#  array([   6, 5722,    4,   54], dtype=int32),
#  array([5722,    4,   54,  388], dtype=int32),
#  array([  4,  54, 388,  14], dtype=int32),
#  array([ 54, 388,  14, 163], dtype=int32),
#  array([388,  14, 163,  29], dtype=int32),
#  array([ 14, 163,  29,   8], dtype=int32),
#  array([163,  29,   8,   7], dtype=int32),
#  array([29,  8,  7,  9], dtype=int32),
#  array([  8,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 210], dtype=int32),
#  array([  9, 104, 210,   7], dtype=int32),
#  array([104, 210,   7,   9], dtype=int32),
#  array([210,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 759], dtype=int32),
#  array([  9, 104, 759,   7], dtype=int32),
#  array([104, 759,   7,   9], dtype=int32),
#  array([759,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 408], dtype=int32),
#  array([  9, 104, 408,   7], dtype=int32),
#  array([104, 408,   7, 121], dtype=int32),
#  array([408,   7, 121,  11], dtype=int32),
#  array([   7,  121,   11, 1044], dtype=int32),
#  array([ 121,   11, 1044,    7], dtype=int32),
#  array([  11, 1044,    7,    9], dtype=int32),
#  array([1044,    7,    9,  104], dtype=int32),
#  array([  7,   9, 104, 157], dtype=int32),
#  array([  9, 104, 157,   7], dtype=int32),
#  array([104, 157,   7,   9], dtype=int32),
#  array([157,   7,   9, 104], dtype=int32),
#  array([   7,    9,  104, 1142], dtype=int32),
#  array([   9,  104, 1142,    1], dtype=int32),
#  array([ 104, 1142,    1,  261], dtype=int32),
#  array([1142,    1,  261,   29], dtype=int32),
#  array([  1, 261,  29,  31], dtype=int32),
#  array([261,  29,  31,  67], dtype=int32),
#  array([29, 31, 67,  1], dtype=int32),
#  array([31, 67,  1, 23], dtype=int32),
#  array([67,  1, 23, 71], dtype=int32),
#  array([ 1, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34,  1], dtype=int32),
#  array([ 7, 34,  1, 40], dtype=int32),
#  array([34,  1, 40,  6], dtype=int32),
#  array([  1,  40,   6, 210], dtype=int32),
#  array([  40,    6,  210, 2712], dtype=int32),
#  array([   6,  210, 2712,  461], dtype=int32),
#  array([ 210, 2712,  461,    6], dtype=int32),
#  array([2712,  461,    6, 5761], dtype=int32),
#  array([ 461,    6, 5761, 2712], dtype=int32),
#  array([   6, 5761, 2712,   28], dtype=int32),
#  array([5761, 2712,   28,   57], dtype=int32),
#  array([2712,   28,   57,   25], dtype=int32),
#  array([28, 57, 25, 10], dtype=int32),
#  array([ 57,  25,  10, 210], dtype=int32),
#  array([  25,   10,  210, 2712], dtype=int32),
#  array([  10,  210, 2712,    7], dtype=int32),
#  array([ 210, 2712,    7,    9], dtype=int32),
#  array([2712,    7,    9,  104], dtype=int32),
#  array([  7,   9, 104, 157], dtype=int32),
#  array([  9, 104, 157,   1], dtype=int32),
#  array([104, 157,   1, 220], dtype=int32),
#  array([157,   1, 220,  29], dtype=int32),
#  array([  1, 220,  29,  31], dtype=int32),
#  array([220,  29,  31,  67], dtype=int32),
#  array([29, 31, 67,  1], dtype=int32),
#  array([31, 67,  1, 23], dtype=int32),
#  array([67,  1, 23, 71], dtype=int32),
#  array([ 1, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34,  1], dtype=int32),
#  array([ 7, 34,  1,  1], dtype=int32),
#  array([ 34,   1,   1, 220], dtype=int32),
#  array([  1,   1, 220,  29], dtype=int32),
#  array([  1, 220,  29,  31], dtype=int32),
#  array([220,  29,  31,  67], dtype=int32),
#  array([29, 31, 67,  1], dtype=int32),
#  array([31, 67,  1, 23], dtype=int32),
#  array([67,  1, 23, 71], dtype=int32),
#  array([ 1, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34,  1], dtype=int32),
#  array([ 7, 34,  1,  1], dtype=int32),
#  array([ 34,   1,   1, 261], dtype=int32),
#  array([  1,   1, 261,  29], dtype=int32),
#  array([  1, 261,  29,  31], dtype=int32),
#  array([261,  29,  31,  67], dtype=int32),
#  array([29, 31, 67,  1], dtype=int32),
#  array([31, 67,  1, 23], dtype=int32),
#  array([67,  1, 23, 71], dtype=int32),
#  array([ 1, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34,  1], dtype=int32),
#  array([ 7, 34,  1,  1], dtype=int32),
#  array([34,  1,  1, 23], dtype=int32),
#  array([ 1,  1, 23, 71], dtype=int32),
#  array([ 1, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34,  1], dtype=int32),
#  array([ 7, 34,  1, 23], dtype=int32),
#  array([34,  1, 23, 71], dtype=int32),
#  array([ 1, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34,  1], dtype=int32),
#  array([  7,  34,   1, 220], dtype=int32),
#  array([ 34,   1, 220,  29], dtype=int32),
#  array([  1, 220,  29,  31], dtype=int32),
#  array([220,  29,  31,  67], dtype=int32),
#  array([29, 31, 67,  1], dtype=int32),
#  array([31, 67,  1, 23], dtype=int32),
#  array([67,  1, 23, 71], dtype=int32),
#  array([ 1, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34,  7], dtype=int32),
#  array([ 7, 34,  7,  9], dtype=int32),
#  array([ 34,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 210], dtype=int32),
#  array([  9, 104, 210,   7], dtype=int32),
#  array([104, 210,   7,   9], dtype=int32),
#  array([210,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 759], dtype=int32),
#  array([  9, 104, 759,   7], dtype=int32),
#  array([104, 759,   7,   9], dtype=int32),
#  array([759,   7,   9, 104], dtype=int32),
#  array([  7,   9, 104, 408], dtype=int32),
#  array([  9, 104, 408,   7], dtype=int32),
#  array([104, 408,   7, 121], dtype=int32),
#  array([408,   7, 121,  11], dtype=int32),
#  array([   7,  121,   11, 1044], dtype=int32),
#  array([ 121,   11, 1044,    7], dtype=int32),
#  array([  11, 1044,    7,    9], dtype=int32),
#  array([1044,    7,    9,  104], dtype=int32),
#  array([  7,   9, 104, 157], dtype=int32),
#  array([  9, 104, 157,   7], dtype=int32),
#  array([104, 157,   7,   9], dtype=int32),
#  array([157,   7,   9, 104], dtype=int32),
#  array([   7,    9,  104, 1142], dtype=int32),
#  array([   9,  104, 1142,   57], dtype=int32),
#  array([ 104, 1142,   57,  261], dtype=int32),
#  array([1142,   57,  261,   29], dtype=int32),
#  array([ 57, 261,  29,  31], dtype=int32),
#  array([261,  29,  31,  67], dtype=int32),
#  array([29, 31, 67, 57], dtype=int32),
#  array([31, 67, 57, 23], dtype=int32),
#  array([67, 57, 23, 71], dtype=int32),
#  array([57, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([71,  7, 34, 57], dtype=int32),
#  array([ 7, 34, 57, 40], dtype=int32),
#  array([34, 57, 40,  6], dtype=int32),
#  array([ 57,  40,   6, 210], dtype=int32),
#  array([  40,    6,  210, 2712], dtype=int32),
#  array([   6,  210, 2712,  461], dtype=int32),
#  array([ 210, 2712,  461,    6], dtype=int32),
#  array([2712,  461,    6, 5761], dtype=int32),
#  array([ 461,    6, 5761, 2712], dtype=int32),
#  array([   6, 5761, 2712,  461], dtype=int32),
#  array([5761, 2712,  461,    6], dtype=int32),
#  array([2712,  461,    6, 5761], dtype=int32),
#  array([ 461,    6, 5761, 2712], dtype=int32),
#  array([   6, 5761, 2712,    1], dtype=int32),
#  array([5761, 2712,    1,   25], dtype=int32),
#  array([2712,    1,   25,  113], dtype=int32),
#  array([  1,  25, 113, 210], dtype=int32),
#  array([  25,  113,  210, 2712], dtype=int32),
#  array([ 113,  210, 2712,    7], dtype=int32),
#  array([ 210, 2712,    7,    9], dtype=int32),
#  array([2712,    7,    9,  104], dtype=int32),
#  array([  7,   9, 104, 157], dtype=int32),
#  array([  9, 104, 157,  57], dtype=int32),
#  array([104, 157,  57, 220], dtype=int32),
#  array([157,  57, 220,  29], dtype=int32),
#  array([ 57, 220,  29,  31], dtype=int32),
#  array([220,  29,  31,  67], dtype=int32),
#  array([29, 31, 67, 57], dtype=int32),
#  array([31, 67, 57, 23], dtype=int32),
#  array([67, 57, 23, 71], dtype=int32),
#  array([57, 23, 71,  7], dtype=int32),
#  array([23, 71,  7, 34], dtype=int32),
#  array([  71,    7,   34, 2712], dtype=int32),
#  array([   7,   34, 2712,   24], dtype=int32),
#  array([  34, 2712,   24,  210], dtype=int32),
#  array([2712,   24,  210,    3], dtype=int32),
#  array([ 24, 210,   3, 237], dtype=int32),
#  array([ 210,    3,  237, 1579], dtype=int32),
#  array([   3,  237, 1579,    1], dtype=int32),
#  array([ 237, 1579,    1,   40], dtype=int32),
#  array([1579,    1,   40,  123], dtype=int32),
#  array([  1,  40, 123, 444], dtype=int32),
#  array([ 40, 123, 444,   4], dtype=int32),
#  array([123, 444,   4,  81], dtype=int32),
#  array([444,   4,  81,  29], dtype=int32),
#  array([ 4, 81, 29,  1], dtype=int32),
#  array([81, 29,  1, 18], dtype=int32),
#  array([29,  1, 18, 13], dtype=int32),
#  array([  1,  18,  13, 249], dtype=int32),
#  array([  18,   13,  249, 2712], dtype=int32),
#  array([  13,  249, 2712,   24], dtype=int32),
#  array([ 249, 2712,   24,  408], dtype=int32),
#  array([2712,   24,  408,   44], dtype=int32),
#  array([ 24, 408,  44,   3], dtype=int32),
#  array([408,  44,   3,  88], dtype=int32),
#  array([44,  3, 88, 11], dtype=int32),
#  array([ 3, 88, 11, 30], dtype=int32),
#  array([88, 11, 30,  1], dtype=int32),
#  array([11, 30,  1, 26], dtype=int32),
#  array([30,  1, 26, 11], dtype=int32),
#  array([ 1, 26, 11, 94], dtype=int32),
#  array([26, 11, 94, 35], dtype=int32),
#  array([ 11,  94,  35, 357], dtype=int32),
#  array([ 94,  35, 357,   1], dtype=int32),
#  array([ 35, 357,   1,  23], dtype=int32),
#  array([357,   1,  23, 272], dtype=int32),
#  array([  1,  23, 272,   7], dtype=int32),
#  array([ 23, 272,   7,  27], dtype=int32)]

# %%
type(sequences_pad[0])
# Out:
# numpy.ndarray

# %% [markdown]
# Create matrix of embeddings to use in the first layer of the neural net to map indices (words) to their correct embeddings.

# %%
# Dictionary from index to word (and vice versa)
word_index_dict = tokenizer.word_index
index_word_dict = dict(map(reversed, word_index_dict.items()))
print('Found %s unique tokens.' % len(word_index_dict))

vocab_size = len(word_index_dict) # Only terms appearing in the specific genre
embed_size = 100
embedding_matrix = np.zeros((vocab_size + 1, embed_size)) # First row will stay at zeros for padding index: 0

for word, i in word_index_dict.items():
    embedding_vector = voc_embeds_dict[word]
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# Found 84951 unique tokens.

# %% [markdown]
# Model creation:

# %%
model = Sequential()
embed = Embedding(len(embedding_matrix), embed_size, weights=[embedding_matrix], input_length = 1, mask_zero = True, trainable=False)
model.add(embed)

t = sequences_pad[0][:5]
print(t)
model.predict(t)
# Out:
# [ 47  64  77   3 497]
# array([[[ 0.10379  ,  0.32986  , -0.34839  ,  0.070715 , -0.22461  ,
#           0.06979  ,  0.046826 ,  0.28013  ,  0.080266 , -0.091009 ,
#          -0.086079 ,  0.60234  ,  0.61265  ,  0.20444  , -0.24218  ,
#           0.19384  , -0.25945  ,  0.23119  , -0.10847  , -0.053188 ,
#          -0.088627 , -0.37306  , -0.17445  , -0.12089  ,  0.20406  ,
#          -0.47211  ,  0.074021 ,  0.22309  ,  0.26263  , -0.077209 ,
#          -0.054993 ,  0.045765 , -0.33694  ,  0.090265 ,  0.061225 ,
#          -0.031373 ,  0.34355  , -0.0080525, -0.078579 , -0.3383   ,
#          -0.0084812,  0.26118  , -0.1201   ,  0.020674 ,  0.011981 ,
#          -0.0098026, -0.067438 ,  0.097171 ,  0.33965  , -0.17555  ,
#           0.38893  , -0.095315 , -0.1466   , -0.087356 ,  0.090826 ,
#          -0.62537  ,  0.26035  ,  0.12335  ,  0.35735  ,  0.15872  ,
#           0.082386 ,  0.42808  ,  0.034145 ,  0.18829  , -0.098424 ,
#           0.10311  ,  0.082719 , -0.20298  ,  0.26479  ,  0.073556 ,
#           0.024633 , -0.34269  ,  0.025242 ,  0.38889  ,  0.27929  ,
#           0.17902  , -0.25768  ,  0.38272  , -0.10662  ,  0.25424  ,
#          -0.59643  , -0.18685  ,  0.53206  , -0.053708 ,  0.28545  ,
#           0.32067  ,  0.36375  , -0.26708  , -0.56686  ,  0.36197  ,
#           0.45635  , -0.28119  , -0.1144   ,  0.25979  , -0.059353 ,
#          -0.090465 ,  0.33231  ,  0.20637  ,  0.28965  , -0.024036 ]],
#
#        [[ 0.22613  , -0.0019628,  0.023602 ,  0.2059   , -0.10258  ,
#           0.265    ,  0.47593  , -0.055178 ,  0.027975 , -0.082653 ,
#          -0.17654  ,  0.2723   ,  0.25515  , -0.022762 , -0.17908  ,
#          -0.070492 , -0.28101  , -0.071644 ,  0.12442  , -0.02659  ,
#          -0.15284  , -0.11615  ,  0.40387  ,  0.056233 ,  0.05139  ,
#          -0.3603   ,  0.052519 ,  0.18406  ,  0.010435 ,  0.036825 ,
#           0.044504 ,  0.17549  , -0.10484  ,  0.071571 , -0.032462 ,
#           0.093353 ,  0.52743  ,  0.045713 , -0.016317 , -0.12274  ,
#          -0.10107  ,  0.17759  , -0.11489  ,  0.39949  ,  0.22228  ,
#          -0.0011059, -0.21604  ,  0.26112  , -0.053024 , -0.062894 ,
#           0.31258  ,  0.14004  , -0.40073  ,  0.046208 ,  0.19398  ,
#          -0.33043  ,  0.33302  ,  0.32776  , -0.15139  ,  0.085665 ,
#          -0.068607 ,  0.119    ,  0.059152 ,  0.10178  , -0.14853  ,
#           0.3399   ,  0.1585   , -0.024132 , -0.18616  ,  0.25132  ,
#          -0.006645 , -0.43795  , -0.34502  ,  0.21291  ,  0.15591  ,
#           0.28328  ,  0.095119 ,  0.15748  , -0.031274 ,  0.042824 ,
#          -0.45546  , -0.21349  ,  0.11098  , -0.19624  ,  0.0045292,
#           0.20734  ,  0.38896  , -0.15354  , -0.59174  ,  0.43515  ,
#           0.37301  , -0.73029  ,  0.018598 ,  0.1177   , -0.41366  ,
#          -0.17621  ,  0.52869  ,  0.092239 ,  0.31288  , -0.057298 ]],
#
#        [[ 0.063201 ,  0.10399  , -0.46572  , -0.035932 , -0.31215  ,
#          -0.061795 ,  0.031008 , -0.16833  ,  0.34857  , -0.12442  ,
#          -0.49734  ,  0.35968  ,  0.22567  , -0.20879  , -0.39593  ,
#          -0.19317  ,  0.082525 ,  0.32559  ,  0.14849  , -0.05113  ,
#          -0.13924  , -0.29931  ,  0.42715  , -0.29124  , -0.062465 ,
#          -0.33056  ,  0.25098  ,  0.2908   ,  0.26006  ,  0.020439 ,
#           0.23304  ,  0.18329  ,  0.12063  , -0.014716 ,  0.16634  ,
#          -0.034629 , -0.064942 ,  0.024791 , -0.35476  , -0.087372 ,
#           0.38091  ,  0.32248  ,  0.23612  ,  0.060997 ,  0.082236 ,
#           0.047337 ,  0.10902  ,  0.047434 , -0.32026  , -0.21024  ,
#           0.34238  , -0.32784  ,  0.072386 , -0.0026741, -0.11896  ,
#          -0.30724  ,  0.064315 ,  0.11177  , -0.2409   ,  0.13156  ,
#          -0.1912   , -0.019222 ,  0.026633 , -0.075111 ,  0.14756  ,
#           0.34762  , -0.32426  , -0.0013634,  0.25023  ,  0.34186  ,
#          -0.15298  , -0.80663  ,  0.021322 ,  0.40207  , -0.31582  ,
#           0.032283 ,  0.19571  ,  0.39542  ,  0.079168 , -0.052856 ,
#          -0.11904  ,  0.060352 , -0.27865  ,  0.32767  ,  0.5188   ,
#           0.28006  ,  0.016218 , -0.054028 , -0.29971  ,  0.38284  ,
#           0.38839  , -0.050971 , -0.21426  ,  0.076931 ,  0.032958 ,
#          -0.19343  ,  0.017431 ,  0.24532  ,  0.1877   , -0.21118  ]],
#
#        [[ 0.18902  ,  0.22337  , -0.31239  ,  0.035155 , -0.44752  ,
#           0.062573 ,  0.21689  , -0.019117 ,  0.311    , -0.10506  ,
#          -0.044379 ,  0.19471  ,  0.10869  , -0.22852  , -0.34014  ,
#           0.13011  , -0.18927  ,  0.011104 ,  0.18052  ,  0.010654 ,
#          -0.12665  , -0.12959  ,  0.46586  ,  0.0068748,  0.16652  ,
#          -0.38074  ,  0.072495 ,  0.17943  , -0.041917 , -0.28619  ,
#           0.0059886,  0.018286 ,  0.16152  , -0.18436  , -0.02479  ,
#          -0.25821  ,  0.23055  ,  0.14532  ,  0.058469 , -0.26494  ,
#           0.010703 ,  0.1949   , -0.047245 ,  0.34795  ,  0.089645 ,
#           0.19222  , -0.09698  ,  0.1838   , -0.11823  , -0.096998 ,
#           0.10306  , -0.061898 , -0.040918 , -0.17424  , -0.010472 ,
#          -0.055848 ,  0.23191  ,  0.058794 , -0.09518  , -0.0063838,
#          -0.077864 ,  0.047449 ,  0.050464 ,  0.11526  ,  0.051969 ,
#           0.33681  , -0.030305 ,  0.086063 , -0.10055  ,  0.20789  ,
#          -0.058579 , -0.43687  , -0.18656  ,  0.17653  ,  0.14474  ,
#          -0.15396  ,  0.15712  ,  0.17143  , -0.0581   , -0.12646  ,
#          -0.15411  ,  0.11059  , -0.18698  , -0.14654  ,  0.17366  ,
#           0.22212  ,  0.22493  ,  0.049179 , -0.46569  ,  0.13681  ,
#           0.26189  , -0.12495  ,  0.060043 ,  0.090109 , -0.19929  ,
#          -0.26414  ,  0.4065   ,  0.28837  ,  0.042246 , -0.15244  ]],
#
#        [[ 0.076493 ,  0.29615  , -0.0085833, -0.34745  , -0.70861  ,
#           0.003105 , -0.231    , -0.22713  ,  0.33182  ,  0.12665  ,
#          -0.10599  ,  0.58212  , -0.14038  , -0.68169  , -0.2724   ,
#          -0.18098  ,  0.37883  , -0.36707  , -0.08222  , -0.50404  ,
#          -0.069233 , -0.31074  ,  0.38382  , -0.036036 , -0.19083  ,
#          -0.78903  ,  0.46758  ,  0.5171   ,  0.34455  , -0.64429  ,
#          -0.27081  ,  0.02153  , -0.20186  ,  0.26633  , -0.12274  ,
#          -0.24111  ,  0.45851  ,  0.13696  ,  0.32382  , -0.37597  ,
#           0.21041  ,  0.41444  ,  0.10394  ,  0.38048  , -0.37323  ,
#           0.042557 ,  0.37112  ,  0.48971  ,  0.14121  , -0.08203  ,
#          -0.027812 ,  0.02314  , -0.045272 ,  0.14487  ,  0.077471 ,
#           0.1053   ,  0.010062 ,  0.67822  , -0.08845  , -0.62088  ,
#           0.18137  ,  0.12618  ,  0.26014  , -0.17886  , -0.1102   ,
#           0.2153   , -0.026987 ,  0.2328   ,  0.22091  , -0.31024  ,
#           0.087396 , -0.46268  , -0.30711  ,  0.85237  , -0.1653   ,
#           0.33402  ,  0.16425  ,  0.051215 ,  0.55285  ,  0.081495 ,
#           0.044864 , -0.56943  , -0.25546  , -0.04878  , -0.049498 ,
#           0.12034  , -0.0076784,  0.15247  , -0.29709  ,  0.38521  ,
#          -0.32062  , -0.13822  ,  0.11558  , -0.072583 , -0.28572  ,
#          -0.33522  ,  0.13433  ,  0.069444 ,  0.34276  , -0.4754   ]]],
#       dtype=float32)

# %%
def create_NN():
    model = Sequential()
    embed = Embedding(len(embedding_matrix), embed_size, weights=[embedding_matrix], input_length = 1, mask_zero = True, trainable = False)
    model.add(embed)
    model.add(LSTM(100))
