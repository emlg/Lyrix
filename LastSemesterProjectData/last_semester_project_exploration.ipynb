# %% [markdown]
# Exploring the datasets from last semester project done by Marta Kuziora.

# %%
import numpy as np
import pandas as pd
from langdetect import detect
import matplotlib.pyplot as plt
import time

filepath = "../../kaggleDataset/marta_datasets/"

# %%
artists_df = pd.read_csv(filepath + 'artist_features.csv')
artists_df.head()
# Out:
#                       _id  followers                                 mb_id  \
# 0  3XSyTI9ct70ZheMESAv2st     3752.0  290e5513-55d3-426f-a4ba-1ac3ce589107
# 1  2jYHSJBXjusgmYdrNeaRmg     1361.0  09cddf26-fe4a-493e-bb1d-64723892ed8d
# 2  5LmehwqsJa7a4Ya5SaqXpx     1147.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
# 3  10BFTSAfLauhKVmdby4zac        0.0  3a8ecc10-f888-48c0-9674-5c0ccd1fe93f
# 4  4hwEAtCJZa1LMgbuRpUWJB        4.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
#
#    popularity reduced_genres gender    type  danceability   energy  key  \
# 0        61.0   ['broadway']      2  Person        0.5459  0.44010  6.4
# 1        29.0       ['jazz']      2  Person        0.6975  0.55410  5.8
# 2        37.0    ['doo-wop']      0   Group        0.5071  0.55695  6.1
# 3         0.0             []      0   Group           NaN      NaN  NaN
# 4         0.0             []      0   Group           NaN      NaN  NaN
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
artist_songs_df = pd.read_csv(filepath + 'artist_songs.csv')
artist_songs_df.head()
# Out:
#                       _id  followers                                 mb_id  \
# 0  3XSyTI9ct70ZheMESAv2st     3752.0  290e5513-55d3-426f-a4ba-1ac3ce589107
# 1  2jYHSJBXjusgmYdrNeaRmg     1361.0  09cddf26-fe4a-493e-bb1d-64723892ed8d
# 2  5LmehwqsJa7a4Ya5SaqXpx     1147.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
# 3  10BFTSAfLauhKVmdby4zac        0.0  3a8ecc10-f888-48c0-9674-5c0ccd1fe93f
# 4  4hwEAtCJZa1LMgbuRpUWJB        4.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
#
#    popularity reduced_genres gender    type  begin_date_year  danceability  \
# 0        61.0   ['broadway']      2  Person           1980.0        0.5459
# 1        29.0       ['jazz']      2  Person           1960.0        0.6975
# 2        37.0    ['doo-wop']      0   Group           1956.0        0.5071
# 3         0.0             []      0   Group           1965.0           NaN
# 4         0.0             []      0   Group           1956.0           NaN
#
# ...

# %%
dataset_df = pd.read_csv(filepath + 'dataset.csv')
print("Number of artists: {}".format(len(dataset_df)))
dataset_df.head()
# Out:
# Number of artists: 739298
#    Unnamed: 0                     _id  followers  \
# 0           0  3XSyTI9ct70ZheMESAv2st     3752.0
# 1           1  2jYHSJBXjusgmYdrNeaRmg     1361.0
# 2           2  5LmehwqsJa7a4Ya5SaqXpx     1147.0
# 3           3  10BFTSAfLauhKVmdby4zac        0.0
# 4           4  4hwEAtCJZa1LMgbuRpUWJB        4.0
#
#                            genres                                 mb_id  \
# 0                    ['broadway']  290e5513-55d3-426f-a4ba-1ac3ce589107
# 1  ['jazz guitar', 'smooth jazz']  09cddf26-fe4a-493e-bb1d-64723892ed8d
# 2                     ['doo-wop']  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
# 3                              []  3a8ecc10-f888-48c0-9674-5c0ccd1fe93f
# 4                              []  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
#
#                       name  popularity reduced_genres   gender    type
# 0             Zachary Levi        61.0   ['broadway']     Male  Person
# ...

# %%
artist_song_features_df = pd.read_csv(filepath + 'artist_song_features.csv')
artist_song_features_df.head()
# Out:
#    Unnamed: 0               artist_id                 song_id  danceability  \
# 0           0  3XSyTI9ct70ZheMESAv2st  1yh793k8lDYfXv3DhHaIXC         0.236
# 1           2  3XSyTI9ct70ZheMESAv2st  0TCt7OFRdD8PQ6vTRQxNgQ         0.625
# 2           6  3XSyTI9ct70ZheMESAv2st  0d2yIwPD2dLNFqrOye5qN2         0.529
# 3           7  3XSyTI9ct70ZheMESAv2st  2xB0yPkGvwuPXiaOVHYnwX         0.438
# 4           8  3XSyTI9ct70ZheMESAv2st  74VcKerwPq5WSOkXSCZ6vi         0.525
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.162  5.0   -14.536   1.0       0.0305         0.842          0.000002
# 1   0.567  4.0    -7.385   1.0       0.1040         0.596          0.000000
# 2   0.477  8.0    -8.237   1.0       0.2120         0.736          0.000000
# 3   0.364  2.0   -12.162   1.0       0.0496         0.715          0.000000
# 4   0.571  6.0    -8.935   0.0       0.1550         0.607          0.000000
#
#    liveness  valence    tempo  duration_ms
# ...

# %%
songs_lyrics_df = pd.read_csv(filepath + 'songs_lyrics.csv')
print("Number of songs: {}".format(len(songs_lyrics_df)))
songs_lyrics_df.head()
# Out:
# Number of songs: 225654
#    Unnamed: 0           artist_id                                 mb_id  \
# 0          10  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 1          14  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 2          74  AR00A6H1187FB5402A  312c14d9-7897-4608-944a-c5b1c76ae682
# 3          75  AR00A6H1187FB5402A  312c14d9-7897-4608-944a-c5b1c76ae682
# 4          76  AR00A6H1187FB5402A  312c14d9-7897-4608-944a-c5b1c76ae682
#
#     artist_name                 tid  \
# 0  The Bristols  TRAFPWS12903CDF737
# 1  The Bristols  TREKDCH128F92EBFDC
# 2   The Meatmen  TRTFZQL12903CB84FC
# 3   The Meatmen  TRLHFUR12903CB852D
# 4   The Meatmen  TRSCFMS12903CB84ED
#
#                                                title  tid_mxm_x  tid_mxm_y  \
# 0                                       I'll Be Gone  3549344.0    3549344
# 1                       Can't You See That He's Mine  3701180.0    3701180
# ...
